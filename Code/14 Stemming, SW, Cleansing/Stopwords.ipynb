# %%
# This code will remove all punctuation from the text and print the following output:
import nltk
nltk.download('stopwords')
import re
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

text = "This is a sentence with stop words."
words = text.split()
clean_words = [word for word in words if word not in stop_words]
clean_text = " ".join(clean_words)
print(clean_text)
# Out:
# This sentence stop words.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# stop_words

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'would', 'at', 'together', 'any', 'four', 'more', 'anyone', 'serious', 'move', 'mine', 'wherever', 'yourselves', 'really', 'also', 'further', 'seem', 'where', 'above', 'not', 'eleven', 'those', 'might', 'seemed', 'bottom', 'formerly', 'all', 'everything', 'may', 'itself', 'these', 'thence', 'several', 'back', 'same', 'hereafter', 'could', 'again', 'then', 'two', 'as', 'herself', 'nothing', 'everyone', 'beside', 'thereupon', 'former', 'beforehand', '‘d', 'when', 'whom', 'yourself', 'me', 'since', 'because', 'though', 'onto', 'done', 'never', 'throughout', 'over', 'i', 'although', 'here', '’d', 'ever', 'top', 'whereafter', 'has', 'between', 'none', 'is', 'must', 'using', 'we', 'to', 'except', 'it', 'will', 'various', 'some', 'his', 'below', 'meanwhile', 'sixty', 'twelve', 'nine', 'seems', 'five', 'have', 'the', '‘ve', 'their', 'behind', 'full', 'toward', 'due', 'for', 'almost', 'nevertheless', 'what', 'even', 'hereby', 'into', 'first', '’s', 'do', 'can', 'there', 'which', 'were', 'amount', 'down', 'too', 'most', 'you', 'by', 'either', 'moreover', 'without', 'had', "'m", 'he', 'afterwards', 'became', 'through', 'thru', 'nowhere', 'hence', 'other', 'within', 'fifty', 'was', 'just', 'twenty', 'elsewhere', 'ca', 'take', 'forty', 'become', 'often', "'ll", 'somewhere', 'via', 'side', "'re", 'something', 'neither', 'much', 'sometime', 'very', 'whereupon', 'against', 'upon', 'an', 'unless', 'why', 'used', 'besides', 'its', 'call', 'amongst', 'six', 'nor', 'a', 'somehow', 'am', 'if', 'latter', 'now', 'few', 'therefore', '‘m', 'however', 'but', 'nobody', '‘re', 'another', 'him', 'ten', 'give', 'one', 'front', 'own', 'my', 'wherein', 'whole', 'go', 'n’t', 'himself', 'hers', 'should', 'up', 'anyway', 'how', '‘ll', 'well', 'enough', 'everywhere', 'whatever', 'show', 'latterly', 'rather', '‘s', 'before', 'three', 'regarding', 'with', 'less', 'whereas', 'made', 'quite', 'on', 'else', 'next', 'been', 'fifteen', 'themselves', 'thereafter', 'so', 'while', 'among', 'such', 'thus', 'namely', '’ve', 'already', 'mostly', 'or', 'per', 'of', 'off', 'does', 'put', 'sometimes', 'after', 'her', 'us', 'otherwise', 'herein', 'towards', 'last', 'your', 'whether', 'did', "n't", 'both', 'this', 'perhaps', 'in', 'becoming', 'under', 'alone', '’re', 'becomes', 'therein', 'that', 'along', 'anything', 'until', 'seeming', 'hundred', 'indeed', 'still', 'no', 'anywhere', 'than', "'d", 'please', 'around', 'doing', 'whenever', 'anyhow', 'part', 'least', '’m', 'thereby', 'always', 'keep', 'are', 'out', 'from', 'during', 'make', 'others', '’ll', 'get', 'many', 'each', 'eight', 'every', 'someone', 'our', 'see', 'they', 'across', 're', 'whoever', 'name', "'s", 'ours', 'noone', "'ve", 'third', 'say', 'beyond', 'n‘t', 'only', 'be', 'once', 'empty', 'and', 'whose', 'being', 'yours', 'myself', 'she', 'whither', 'whence', 'about', 'cannot', 'who', 'hereupon', 'whereby', 'ourselves', 'them', 'yet'}

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.vocab['beyond'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %%
my_sw = ['i','he','she','it','my','your','his','him','her']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words
# Out:
# 179
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
example_sent = "This is a sample sentence, And This showing off the stop words filtration."
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)
word_tokens
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'sentence',
#  ',',
#  'And',
#  'This',
#  'showing',
#  'off',
#  'the',
#  'stop',
#  'words',
#  'filtration',
#  '.']

# %%
# filtered_sentence = [w for w in word_tokens]

# print(word_tokens)
# print('---------------------------------')
# print(filtered_sentence)

# %%
filtered_sentence = [w for w in word_tokens if not w in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['This', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'stop', 'words', 'filtration', '.']

# %%
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
Ar_SW1 = set(nltk.corpus.stopwords.words("arabic"))
print(len(Ar_SW1))
' | '.join(Ar_SW1)
# Out:
# 701
# 'إنَّ | هيهات | خلف | بضع | أفعل به | منذ | هَذا | عل | إحدى | أنًّ | ستمئة | منها | مئتان | تفعلون | حَذارِ | لم | ريال | ألفى | ذواتا | آه | أجمع | دواليك | هلّا | ضحوة | آ | نيف | عدا | لكم | هما | لي | أرى | خبَّر | سرعان | إلَيْكَ | مارس | خ | ذا | التي | حمٌ | تعسا | بهم | أمسى | هؤلاء | يا | بخٍ | أوه | ما أفعله | خمسين | أقبل | نفس | ف | حادي | إياك | حاء | نحن | لك | لوما | يوان | كلّما | إياكن | أيضا | هل | ألف | ثلاثاء | سبعمائة | كانون | ومن | اربعون | خمسمائة | بغتة | إنما | كأن | به | رويدك | مافتئ | فإذا | فلس | تسعمئة | حمو | لن | أُفٍّ | نَخْ | هيا | عشرة | د | مكانَك | حرى | س | ء | ثاني | ريث | شين | أربع | بس | ذي | فيفري | أنتم | تلقاء | ماي | شرع | يفعلون | تاسع | بهن | إذا | أربعة | اللذان | إلّا | مثل | شبه | دولار | ذلك | غين | أيها | تسعين | درهم | هيّا | ما | لدن | أقل | بَسْ | هذان | إن | ين | ثمانين | حمدا | صاد | أغسطس | إذ | ثامن | فاء | بكن | بعض | شيكل | سبتمبر | شمال | ارتدّ | ميم | لا سيما | ث | عَدَسْ | ثمّة | سبعمئة | آهِ | غادر | أخو |
/usr/local/lib/python3.10/dist-packages (0.4.3)
# Requirement already satisfied: pyarabic>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from Arabic-Stopwords) (0.6.15)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic>=0.6.2->Arabic-Stopwords) (1.16.0)

# %%
import arabicstopwords.arabicstopwords as stp

# %%
len(stp.classed_stopwords_list())
# Out:
# 508

# %%
stp.classed_stopwords_list()
# Out:
# dict_keys(['أن', 'إن', 'عل', 'كأن', 'لعل', 'لكن', 'ليت', 'ثنا', 'بيد', 'سوى', 'غير', 'لاسيما', 'أولئك', 'أولئكم', 'أولاء', 'أولالك', 'تان', 'تانك', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'ذا', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذوا', 'ذواتا', 'ذواتي', 'ذوو', 'ذوي', 'ذي', 'ذين', 'ذينك', 'كذلك', 'هؤلاء', 'هاتان', 'هاته', 'هاتي', 'هاتين', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا', 'هنا', 'هناك', 'هنالك', 'أي', 'إذ', 'إذا', 'ابن', 'بعض', 'تجاه', 'تلقاء', 'جميع', 'حسب', 'حيث', 'سبحان', 'شبه', 'شطر', 'كل', 'لعمر', 'لما', 'مثل', 'مع', 'معاذ', 'نحو', 'متى', 'أنى', 'أيان', 'أين', 'بكم', 'بما', 'بماذا', 'بمن', 'كم', 'كيف', 'ما', 'ماذا', 'مما', 'ممن', 'من', 'أينما', 'حيثما', 'كيفما', 'مهما', 'أقل', 'أكثر', 'آها', 'بس', 'حاي', 'صه', 'طاق', 'طق', 'عدس', 'كخ', 'نخ', 'هج', 'وا', 'واها', 'وي', 'آمين', 'آه', 'أف', 'أمامك', 'أوه', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'إيه', 'بخ', 'بطآن', 'بله', 'حذار', 'حي', 'دونك', 'رويدك', 'سرعان', 'شتان', 'عليك', 'مكانك', 'مكانكم', 'مكانكما', 'مكانكن', 'مه', 'ها', 'هاؤم', 'هاك', 'هلم', 'هيا', 'هيت', 'هيهات', 'وراءك', 'وشكان', 'ويكأن', 'الألاء', 'الألى', 'التي', 'الذي', 'الذين', 'اللائي', 'اللاتي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'ذات', 'أب', 'أبا', 'أبو', 'أبي', 'أخ', 'أخا', 'أخو', 'أخي', 'حم', 'حما', 'حمو', 'حمي', 'ذو', 'فا', 'فو', 'في', 'لن', 'لو', 'لولا', 'لوما', 'نعم', 'بئس', 'حبذا', 'ساء', 'ساءما', 'نعما', 'لا', 'لات', 'حتى', 'كي', 'أجمع', 'عامة', 'عين', 'كلا', 'كلاهما', 'كلتا', 'كليكما', 'كليهما', 'نفس', 'ء', 'آ', 'أ', 'ؤ', 'ئ', 'ب', 'ة', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', '
متما', 'مادمتم', 'مادمتن', 'مادامت', 'ماداما', 'مادامتا', 'ماداموا', 'مادمن', 'مابرحت', 'مابرحنا', 'مابرحتما', 'مابرحتم', 'مابرحتن', 'مابرحا', 'مابرحتا', 'مابرحوا', 'مابرحن', 'مافتئت', 'مافتئنا', 'مافتئتما', 'مافتئتم', 'مافتئتن', 'مافتئا', 'مافتئتا', 'مافتئوا', 'مافتئن', 'ماانفككت', 'ماانفككنا', 'ماانفككتما', 'ماانفككتم', 'ماانفككتن', 'ماانفكت', 'ماانفكا', 'ماانفكتا', 'ماانفكوا', 'ماانفككن'])

# %%
len(stp.stopwords_list())
# Out:
# 13465

# %%
stp.stopwords_list()
# Out:
# ['أن',
#  'أنك',
#  'أنكما',
#  'أنكم',
#  'أنكن',
#  'أننا',
#  'أنها',
#  'أنه',
#  'أنهما',
#  'أنهم',
#  'أنهن',
#  'أني',
#  'بأن',
#  'بأنك',
#  'بأنكما',
#  'بأنكم',
#  'بأنكن',
#  'بأننا',
#  'بأنها',
#  'بأنه',
#  'بأنهما',
#  'بأنهم',
#  'بأنهن',
#  'بأني',
#  'فأن',
#  'فأنك',
#  'فأنكما',
#  'فأنكم',
#  'فأنكن',
#  'فأننا',
#  'فأنها',
#  'فأنه',
#  'فأنهما',
#  'فأنهم',
#  'فأنهن',
#  'فأني',
#  'فبأن',
#  'فبأنك',
#  'فبأنكما',
#  'فبأنكم',
#  'فبأنكن',
#  'فبأننا',
#  'فبأنها',
#  'فبأنه',
#  'فبأنهما',
#  'فبأنهم',
#  'فبأنهن',
#  'فبأني',
#  'فكأن',
#  'فكأنك',
#  'فكأنكما',
#  'فكأنكم',
#  'فكأنكن',
#  'فكأننا',
#  'فكأنها',
#  'فكأنه',
#  'فكأنهما',
#  'فكأنهم',
#  'فكأنهن',
#  'فكأني',
#  'فلأن',
#  'فلأنك',
#  'فلأنكما',
#  'فلأنكم',
#  'فلأنكن',
#  'فلأننا',
#  'فلأنها',
#  'فلأنه',
#  'فلأنهما',
#  'فلأنهم',
#  'فلأنهن',
#  'فلأني',
#  'كأن',
#  'كأنك',
#  'كأنكما',
#  'كأنكم',
#  'كأنكن',
#  'كأننا',
#  'كأنها',
#  'كأنه',
#  'كأنهما',
#  'كأنهم',
#  'كأنهن',
#  'كأني',
#  'لأن',
#  'لأنك',
#  'لأنكما',
#  'لأنكم',
#  'لأنكن',
#  'لأننا',
#  'لأنها',
#  'لأنه',
#  'لأنهما',
#  'لأنهم',
#  'لأنهن',
#  'لأني',
#  'وأن',
#  'وأنك',
#  'وأنكما',
#  'وأنكم',
#  'وأنكن',
#  'وأننا',
#  'وأنها',
#  'وأنه',
#  'وأنهما',
#  'وأنهم',
#  'وأنهن',
#  'وأني',
#  'وبأن',
#  'وبأنك',
#  'وبأنكما',
#  'وبأنكم',
#  'وبأنكن',
#  'وبأننا',
#  'وبأنها',
#  'وبأنه',
#  'وبأنهما',
#  'وبأنهم',
#  'وبأنهن',
#  'وبأني',
#  'وكأن',
#  'وكأنك',
#  'وكأنكما',
#  'وكأنكم',
#  'وكأنكن',
#  'وكأننا',
#  'وكأنها',
#  'وكأنه',
#  'وكأنهما',
#  'وكأنهم',
#  'وكأنهن',
#  'وكأني',
#  'ولأن',
#  'ولأنك',
#  'ولأنكما',
#  'ولأنكم',
#  'ولأنكن',
#  'ولأننا',
#  'ولأنها',
#  'ولأنه',
#  'ولأنهما',
#  'ولأنهم',
#  'ولأنهن',
#  'ولأني',
#  'إن',
#  'إنك',
#  'إنكما',
#  'إنكم',
#  'إنكن',
#  'إننا',
#  'إنها',
#  'إنه',
#  'إنهما',
#  'إنهم',
#  'إنهن',
#  'إني',
#  'أإن',
#  'أإنك',
#  'أإنكما',
#  'أإنكم',
#  'أإنكن',
#  'أإننا',
#  'أإنها',
#  'أإنه',
#  'أإنهما',
#  'أإنهم',
#  'أإنهن',
#  'أإني',
#  'أفإن',
#  'أفإنك',
#  'أفإنكما',
#  'أفإنكم',
#  'أفإنكن',
#  'أفإننا',
#  'أفإنها',
#  'أفإنه',
#  'أفإنهما',
#  'أفإنهم',
#  'أفإنهن',
#  'أفإني',
#  'أفلإن',
#  'أفلإنك',
#  'أفلإنكما',
#  'أفلإنكم',
#  'أفلإنكن',
#  'أفلإننا',
#  'أفلإنها',
#  'أفلإنه',
#  'أفلإنهما',
#  'أفلإنهم',
#  'أفلإنهن',
#  'أفلإني',
#  'ألإن',
#  'ألإنك',
#  'ألإنكما',
#  'ألإنكم',
#  'ألإنكن',
#  'ألإننا',
#  'ألإنها',
#  'ألإنه',
#  'ألإنهما',
#  'ألإنهم',
#  'ألإنهن',
#  'ألإني',
#  'أوإن',
#  'أوإنك',
#  'أوإنكما',
#  'أوإنكم',
#  'أوإنكن',
#  'أوإننا',
#  'أوإنها',
#  'أوإنه',
#  'أوإنهما',
#  'أوإنهم',
#  'أوإنهن',
#  'أوإني',
#  'أولإن',
#  'أولإنك',
#  'أولإنكما',
#  'أولإنكم',
#  'أولإنكن',
#  'أولإننا',
#  'أولإنها',
#  'أولإنه',
#  'أولإنهما',
#  'أولإنهم',
#  'أولإنهن',
#  'أولإني',
#  'فإن',
#  'فإنك',
#  'فإنكما',
#  'فإنكم',
#  'فإنكن',
#  'فإننا',
#  'فإنها',
#  'فإنه',
#  'فإنهما',
#  'فإنهم',
#  'فإنهن',
#  'فإني',
#  'فلإن',
#  'فلإنك',
#  'فلإنكما',
#  'فلإنكم',
#  'فلإنكن',
#  'فلإننا',
#  'فلإنها',
#  'فلإنه',
#  'فلإنهما',
#  'فلإنهم',
#  'فلإنهن',
#  'فلإني',
#  'وإن',
#  'وإنك',
#  'وإنكما',
#  'وإنكم',
#  'وإنكن',
#  'وإننا',
#  'وإنها',
#  'وإنه',
#  'وإنهما',
#  'وإنهم',
#  'وإنهن',
#  'وإني',
#  'ولإن',
#  'ولإنك',
#  'ولإنكما',
#  'ولإنكم',
#  'ولإنكن',
#  'ولإننا',
#  'ولإنها',
#  'ولإنه',
#  'ولإنهما',
#  'ولإنهم',
#  'ولإنهن',
#  'ولإني',
#  'لإن',
#  'لإنك',
#  'لإنكما',
#  'لإنكم',
#  'لإنكن',
#  'لإننا',
#  'لإنها',
#  'لإنه',
#  'لإنهما',
#  'لإنهم',
#  'لإنهن',
#  'لإني',
#  'عل',
#  'فعل',
#  'وعل',
#  'أكأن',
#  'أكأنك',
#  'أكأنكما',
#  'أكأنكم',
#  'أكأنكن',
#  'أكأننا',
#  'أكأنها',
#  'أكأنه',
#  'أكأنهما',
#  'أكأنهم',
#  'أكأنهن',
#  'أكأني',
#  'أفكأن',
#  'أفكأنك',
#  'أفكأنكما',
#  'أفكأنكم',
#  'أفكأنكن',
#  'أفكأننا',
#  'أفكأنها',
#  'أفكأنه',
#  'أفكأنهما',
#  'أفكأنهم',
#  'أفكأنهن',
#  'أفكأني',
#  'أفلكأن',
#  'أفلكأنك',
#  'أفلكأنكما',
#  'أفلكأنكم',
#  'أفلكأنكن',
#  'أفلكأننا',
#  'أفلكأنها',
#  'أفلكأنه',
#  'أفلكأنهما',
#  'أفلكأنهم',
#  'أفلكأنهن',
#  'أفلكأني',
#  'ألكأن',
#  'ألكأنك',
#  'ألكأنكما',
#  'ألكأنكم',
#  'ألكأنكن',
#  'ألكأننا',
#  'ألكأنها',
#  'ألكأنه',
#  'ألكأنهما',
#  'ألكأنهم',
#  'ألكأنهن',
#  'ألكأني',
#  'أوكأن',
#  'أوكأنك',
#  'أوكأنكما',
#  'أوكأنكم',
#  'أوكأنكن',
#  'أوكأننا',
#  'أوكأنها',
#  'أوكأنه',
#  'أوكأنهما',
#  'أوكأنهم',
#  'أوكأنهن',
#  'أوكأني',
#  'أولكأن',
#  'أولكأنك',
#  'أولكأنكما',
#  'أولكأنكم',
#  'أولكأنكن',
#  'أولكأننا',
#  'أولكأنها',
#  'أولكأنه',
#  'أولكأنهما',
#  'أولكأنهم',
#  'أولكأنهن',
#  'أولكأني',
#  'فلكأن',
#  'فلكأنك',
#  'فلكأنكما',
#  'فلكأنكم',
#  'فلكأنكن',
#  'فلكأننا',
#  'فلكأنها',
#  'فلكأنه',
#  'فلكأنهما',
#  'فلكأنهم',
#  'فلكأنهن',
#  'فلكأني',
#  'ولكأن',
#  'ولكأنك',
#  'ولكأنكما',
#  'ولكأنكم',
#  'ولكأنكن',
#  'ولكأننا',
#  'ولكأنها',
#  'ولكأنه',
#  'ولكأنهما',
#  'ولكأنهم',
#  'ولكأنهن',
#  'ولكأني',
#  'لكأن',
#  'لكأنك',
#  'لكأنكما',
#  'لكأنكم',
#  'لكأنكن',
#  'لكأننا',
#  'لكأنها',
#  'لكأنه',
#  'لكأنهما',
#  'لكأنهم',
#  'لكأنهن',
#  'لكأني',
#  'لعل',
#  'لعلك',
#  'لعلكما',
#  'لعلكم',
#  'لعلكن',
#  'لعلنا',
#  'لعلها',
#  'لعله',
#  'لعلهما',
#  'لعلهم',
#  'لعلهن',
#  'لعلي',
#  'ألعل',
#  'ألعلك',
#  'ألعلكما',
#  'ألعلكم',
#  'ألعلكن',
#  'ألعلنا',
#  'ألعلها',
#  'ألعله',
#  'ألعلهما',
#  'ألعلهم',
#  'ألعلهن',
#  'ألعلي',
#  'أفلعل',
#  'أفلعلك',
#  'أفلعلكما',
#  'أفلعلكم',
#  'أفلعلكن',
#  'أفلعلنا',
#  'أفلعلها',
#  'أفلعله',
#  'أفلعلهما',
#  'أفلعلهم',
#  'أفلعلهن',
#  'أفلعلي',
#  'أولعل',
#  'أولعلك',
#  'أولعلكما',
#  'أولعلكم',
#  'أولعلكن',
#  'أولعلنا',
#  'أولعلها',
#  'أولعله',
#  'أولعلهما',
#  'أولعلهم',
#  'أولعلهن',
#  'أولعلي',
#  'فلعل',
#  'فلعلك',
#  'فلعلكما',
#  'فلعلكم',
#  'فلعلكن',
#  'فلعلنا',
#  'فلعلها',
#  'فلعله',
#  'فلعلهما',
#  'فلعلهم',
#  'فلعلهن',
#  'فلعلي',
#  'ولعل',
#  'ولعلك',
#  'ولعلكما',
#  'ولعلكم',
#  'ولعلكن',
#  'ولعلنا',
#  'ولعلها',
#  'ولعله',
#  'ولعلهما',
#  'ولعلهم',
#  'ولعلهن',
#  'ولعلي',
#  'لكن',
#  'لكنك',
#  'لكنكما',
#  'لكنكم',
#  'لكنكن',
#  'لكننا',
#  'لكنها',
#  'لكنه',
#  'لكنهما',
#  'لكنهم',
#  'لكنهن',
#  'لكني',
#  'فلكن',
#  'فلكنك',
#  'فلكنكما',
#  'فلكنكم',
#  'فلكنكن',
#  'فلكننا',
#  'فلكنها',
#  'فلكنه',
#  'فلكنهما',
#  'فلكنهم',
#  'فلكنهن',
#  'فلكني',
#  'ولكن',
#  'ولكنك',
#  'ولكنكما',
#  'ولكنكم',
#  'ولكنكن',
#  'ولكننا',
#  'ولكنها',
#  'ولكنه',
#  'ولكنهما',
#  'ولكنهم',
#  'ولكنهن',
#  'ولكني',
#  'ليت',
#  'ليتك',
#  'ليتكما',
#  'ليتكم',
#  'ليتكن',
#  'ليتنا',
#  'ليتها',
#  'ليته',
#  'ليتهما',
#  'ليتهم',
#  'ليتهن',
#  'ليتي',
#  'فليت',
#  'فليتك',
#  'فليتكما',
#  'فليتكم',
#  'فليتكن',
#  'فليتنا',
#  'فليتها',
#  'فليته',
#  'فليتهما',
#  'فليتهم',
#  'فليتهن',
#  'فليتي',
#  'وليت',
#  'وليتك',
#  'وليتكما',
#  'وليتكم',
#  'وليتكن',
#  'وليتنا',
#  'وليتها',
#  'وليته',
#  'وليتهما',
#  'وليتهم',
#  'وليتهن',
#  'وليتي',
#  'ثنا',
#  'فثنا',
#  'وثنا',
#  'بيد',
#  'فبيد',
#  'وبيد',
#  'سوى',
#  'فسوى',
#  'وسوى',
#  'غير',
#  'غيرك',
#  'غيركما',
#  'غيركم',
#  'غيركن',
#  'غيرنا',
#  'غيرها',
#  'غيره',
#  'غيرهما',
#  'غيرهم',
#  'غيرهن',
#  'غيري',
#  'أكغيره',
#  'أكغيرهما',
#  'أكغيرهم',
#  'أكغيرهن',
#  'أكغير',
#  'أكغيرك',
#  'أكغيركما',
#  'أكغيركم',
#  'أكغيركن',
#  'أكغيرنا',
#  'أكغيرها',
#  'أكغيري',
#  'أغير',
#  'أغيرك',
#  'أغيركما',
#  'أغيركم',
#  'أغيركن',
#  'أغيرنا',
#  'أغيرها',
#  'أغيره',
#  'أغيرهما',
#  'أغيرهم',
#  'أغيرهن',
#  'أغيري',
#  'أبغيره',
#  'أبغيرهما',
#  'أبغيرهم',
#  'أبغيرهن',
#  'أبغير',
#  'أبغيرك',
#  'أبغيركما',
#  'أبغيركم',
#  'أبغيركن',
#  'أبغيرنا',
#  'أبغيرها',
#  'أبغيري',
#  'أفغير',
#  'أفغيرك',
#  'أفغيركما',
#  'أفغيركم',
#  'أفغيركن',
#  'أفغيرنا',
#  'أفغيرها',
#  'أفغيره',
#  'أفغيرهما',
#  'أفغيرهم',
#  'أفغيرهن',
#  'أفغيري',
#  'أفبغيره',
#  'أفبغيرهما',
#  'أفبغيرهم',
#  'أفبغيرهن',
#  'أفبغير',
#  'أفبغيرك',
#  'أفبغيركما',
#  'أفبغيركم',
#  'أفبغيركن',
#  'أفبغيرنا',
#  'أفبغيرها',
#  'أفبغيري',
#  'أفكغيره',
#  'أفكغيرهما',
#  'أفكغيرهم',
#  'أفكغيرهن',
#  'أفكغير',
#  'أفكغيرك',
#  'أفكغيركما',
#  'أفكغيركم',
#  'أفكغيركن',
#  'أفكغيرنا',
#  'أفكغيرها',
#  'أفكغيري',
#  'أفلغير',
#  'أفلغيرك',
#  'أفلغيركما',
#  'أفلغيركم',
#  'أفلغيركن',
#  'أفلغيرنا',
#  'أفلغيرها',
#  'أفلغيره',
#  'أفلغيرهما',
#  'أفلغيرهم',
#  'أفلغيرهن',
#  'أفلغيري',
#  'ألغير',
#  'ألغيرك',
#  'ألغيركما',
#  'ألغيركم',
#  'ألغيركن',
#  'ألغيرنا',
#  'ألغيرها',
#  'ألغيره',
#  'ألغيرهما',
#  'ألغيرهم',
#  'ألغيرهن',
#  'ألغيري',
#  'أوغير',
#  'أوغيرك',
#  'أوغيركما',
#  'أوغيركم',
#  'أوغيركن',
#  'أوغيرنا',
#  'أوغيرها',
#  'أوغيره',
#  'أوغيرهما',
#  'أوغيرهم',
#  'أوغيرهن',
#  'أوغيري',
#  'أوبغيره',
#  'أوبغيرهما',
#  'أوبغيرهم',
#  'أوبغيرهن',
#  'أوبغير',
#  'أوبغيرك',
#  'أوبغيركما',
#  'أوبغيركم',
#  'أوبغيركن',
#  'أوبغيرنا',
#  'أوبغيرها',
#  'أوبغيري',
#  'أوكغيره',
#  'أوكغيرهما',
#  'أوكغيرهم',
#  'أوكغيرهن',
#  'أوكغير',
#  'أوكغيرك',
#  'أوكغيركما',
#  'أوكغيركم',
#  'أوكغيركن',
#  'أوكغيرنا',
#  'أوكغيرها',
#  'أوكغيري',
#  'أولغير',
#  'أولغيرك',
#  'أولغيركما',
#  'أولغيركم',
#  'أولغيركن',
#  'أولغيرنا',
#  'أولغيرها',
#  'أولغيره',
#  'أولغيرهما',
#  'أولغيرهم',
#  'أولغيرهن',
#  'أولغيري',
#  'بغيره',
#  'بغيرهما',
#  'بغيرهم',
#  'بغيرهن',
#  'بغير',
#  'بغيرك',
#  'بغيركما',
#  'بغيركم',
#  'بغيركن',
#  'بغيرنا',
#  'بغيرها',
#  'بغيري',
#  'فغير',
#  'فغيرك',
#  'فغيركما',
#  'فغيركم',
#  'فغيركن',
#  'فغيرنا',
#  'فغيرها',
#  'فغيره',
#  'فغيرهما',
#  'فغيرهم',
#  'فغيرهن',
#  'فغيري',
#  'فبغيره',
#  'فبغيرهما',
#  'فبغيرهم',
#  'فبغيرهن',
#  'فبغير',
#  'فبغيرك',
#  'فبغيركما',
#  'فبغيركم',
#  'فبغيركن',
#  'فبغيرنا',
#  'فبغيرها',
#  'فبغيري',
#  'فكغيره',
#  'فكغيرهما',
#  'فكغيرهم',
#  'فكغيرهن',
#  'فكغير',
#  'فكغيرك',
#  'فكغيركما',
#  'فكغيركم',
#  'فكغيركن',
#  'فكغيرنا',
#  'فكغيرها',
#  'فكغيري',
#  'فلغير',
#  'فلغيرك',
#  'فلغيركما',
#  'فلغيركم',
#  'فلغيركن',
#  'فلغيرنا',
#  'فلغيرها',
#  'فلغيره',
#  'فلغيرهما',
#  'فلغيرهم',
#  'فلغيرهن',
#  'فلغيري',
#  'كغيره',
#  'كغيرهما',
#  'كغيرهم',
#  'كغيرهن',
#  'كغير',
#  'كغيرك',
#  'كغيركما',
#  'كغيركم',
#  'كغيركن',
#  'كغيرنا',
#  'كغيرها',
#  'كغيري',
#  'لغيره',
#  'لغيرهما',
#  'لغيرهم',
#  'لغيرهن',
#  'لغير',
#  'لغيرك',
#  'لغيركما',
#  'لغيركم',
#  'لغيركن',
#  'لغيرنا',
#  'لغيرها',
#  'لغيري',
#  'وغير',
#  'وغيرك',
#  'وغيركما',
#  'وغيركم',
#  'وغيركن',
#  'وغيرنا',
#  'وغيرها',
#  'وغيره',
#  'وغيرهما',
#  'وغيرهم',
#  'وغيرهن',
#  'وغيري',
#  'وبغيره',
#  'وبغيرهما',
#  'وبغيرهم',
#  'وبغيرهن',
#  'وبغير',
#  'وبغيرك',
#  'وبغيركما',
#  'وبغيركم',
#  'وبغيركن',
#  'وبغيرنا',
#  'وبغيرها',
#  'وبغيري',
#  'وكغيره',
#  'وكغيرهما',
#  'وكغيرهم',
#  'وكغيرهن',
#  'وكغير',
#  'وكغيرك',
#  'وكغيركما',
#  'وكغيركم',
#  'وكغيركن',
#  'وكغيرنا',
#  'وكغيرها',
#  'وكغيري',
#  'ولغير',
#  'ولغيرك',
#  'ولغيركما',
#  'ولغيركم',
#  'ولغيركن',
#  'ولغيرنا',
#  'ولغيرها',
#  'ولغيره',
#  'ولغيرهما',
#  'ولغيرهم',
#  'ولغيرهن',
#  'ولغيري',
#  'لاسيما',
#  'فلاسيما',
#  'ولاسيما',
#  'أولئك',
#  'أكأولئك',
#  'أأولئك',
#  'أبأولئك',
#  'أفأولئك',
#  'أفبأولئك',
#  'أفكأولئك',
#  'أفلأولئك',
#  'ألأولئك',
#  'أوأولئك',
#  'أوبأولئك',
#  'أوكأولئك',
#  'أولأولئك',
#  'بأولئك',
#  'فأولئك',
#  'فبأولئك',
#  'فكأولئك',
#  'فلأولئك',
#  'كأولئك',
#  'لأولئك',
#  'وأولئك',
#  'وبأولئك',
#  'وكأولئك',
#  'ولأولئك',
#  'أولئكم',
#  'أكأولئكم',
#  'أأولئكم',
#  'أبأولئكم',
#  'أفأولئكم',
#  'أفبأولئكم',
#  'أفكأولئكم',
#  'أفلأولئكم',
#  'ألأولئكم',
#  'أوأولئكم',
#  'أوبأولئكم',
#  'أوكأولئكم',
#  'أولأولئكم',
#  'بأولئكم',
#  'فأولئكم',
#  'فبأولئكم',
#  'فكأولئكم',
#  'فلأولئكم',
#  'كأولئكم',
#  'لأولئكم',
#  'وأولئكم',
#  'وبأولئكم',
#  'وكأولئكم',
#  'ولأولئكم',
#  'أولاء',
#  'أكأولاء',
#  'أأولاء',
#  'أبأولاء',
#  'أفأولاء',
#  'أفبأولاء',
#  'أفكأولاء',
#  'أفلأولاء',
#  'ألأولاء',
#  'أوأولاء',
#  'أوبأولاء',
#  'أوكأولاء',
#  'أولأولاء',
#  'بأولاء',
#  'فأولاء',
#  'فبأولاء',
#  'فكأولاء',
#  'فلأولاء',
#  'كأولاء',
#  'لأولاء',
#  'وأولاء',
#  'وبأولاء',
#  'وكأولاء',
#  'ولأولاء',
#  'أولالك',
#  'أكأولالك',
#  'أأولالك',
#  'أبأولالك',
#  'أفأولالك',
#  'أفبأولالك',
#  'أفكأولالك',
#  'أفلأولالك',
#  'ألأولالك',
#  'أوأولالك',
#  'أوبأولالك',
#  'أوكأولالك',
#  'أولأولالك',
#  'بأولالك',
#  'فأولالك',
#  'فبأولالك',
#  'فكأولالك',
#  'فلأولالك',
#  'كأولالك',
#  'لأولالك',
#  'وأولالك',
#  'وبأولالك',
#  'وكأولالك',
#  'ولأولالك',
#  'تان',
#  'فتان',
#  'وتان',
#  'تانك',
#  'بتانك',
#  'فتانك',
#  'فبتانك',
#  'فكتانك',
#  'فلتانك',
#  'كتانك',
#  'لتانك',
#  'وتانك',
#  'وبتانك',
#  'وكتانك',
#  'ولتانك',
#  'تلك',
#  'أكتلك',
#  'أتلك',
#  'أبتلك',
#  'أفتلك',
#  'أفبتلك',
#  'أفكتلك',
#  'أفلتلك',
#  'ألتلك',
#  'أوتلك',
#  'أوبتلك',
#  'أوكتلك',
#  'أولتلك',
#  'بتلك',
#  'فتلك',
#  'فبتلك',
#  'فكتلك',
#  'فلتلك',
#  'كتلك',
#  'لتلك',
#  'وتلك',
#  'وبتلك',
#  'وكتلك',
#  'ولتلك',
#  'تلكم',
#  'أكتلكم',
#  'أتلكم',
#  'أبتلكم',
#  'أفتلكم',
#  'أفبتلكم',
#  'أفكتلكم',
#  'أفلتلكم',
#  'ألتلكم',
#  'أوتلكم',
#  'أوبتلكم',
#  'أوكتلكم',
#  'أولتلكم',
#  'بتلكم',
#  'فتلكم',
#  'فبتلكم',
#  'فكتلكم',
#  'فلتلكم',
#  'كتلكم',
#  'لتلكم',
#  'وتلكم',
#  'وبتلكم',
#  ...]

# %%
stp.is_stop(u'ممكن')
# Out:
# False

# %%
stp.is_stop(u'منكم')
# Out:
# True

# %%
stp.stopword_forms(u"على")
# Out:
# ['أوعلي',
#  'عليكما',
#  'أفلعليكما',
#  'عليكم',
#  'أفعلينا',
#  'لعليها',
#  'أولعليهم',
#  'وعليكن',
#  'فعليهم',
#  'أولعليكما',
#  'أفلعليهن',
#  'فلعليكما',
#  'ألعليكم',
#  'وعليهم',
#  'عليه',
#  'ولعليه',
#  'وعليه',
#  'عليهم',
#  'أعليهم',
#  'أولعليك',
#  'وعليهما',
#  'وعليها',
#  'لعليكن',
#  'ولعليهن',
#  'فلعليك',
#  'فلعليهما',
#  'أوعليكن',
#  'فعلى',
#  'لعليه',
#  'لعليكما',
#  'أفلعلى',
#  'لعليكم',
#  'أفعليهن',
#  'ألعليه',
#  'أفلعليهما',
#  'أعلى',
#  'أعليكما',
#  'فلعلي',
#  'أوعليها',
#  'أفلعليكم',
#  'لعلي',
#  'فلعليهن',
#  'ألعليكن',
#  'لعليك',
#  'ألعليهن',
#  'ألعلى',
#  'وعليكم',
#  'أولعليهما',
#  'أفعلى',
#  'فعليكما',
#  'ألعلي',
#  'أولعليكم',
#  'فلعلينا',
#  'أفلعليكن',
#  'أفلعليها',
#  'ألعلينا',
#  'أعليكم',
#  'أولعلى',
#  'أعليكن',
#  'أفعليهما',
#  'وعلي',
#  'أولعليهن',
#  'أفعليها',
#  'أوعلينا',
#  'فلعلى',
#  'أفعلي',
#  'فلعليه',
#  'أعليك',
#  'فعليهما',
#  'عليكن',
#  'أفلعليك',
#  'أفعليكن',
#  'وعليهن',
#  'أعليه',
#  'فعلي',
#  'ولعليها',
#  'ولعليهما',
#  'أعليهن',
#  'أولعليها',
#  'أعليها',
#  'أفلعليهم',
#  'أفعليهم',
#  'فلعليها',
#  'ولعلي',
#  'أولعليكن',
#  'ولعليهم',
#  'أفعليكما',
#  'أفلعليه',
#  'وعلى',
#  'أوعليه',
#  'أعليهما',
#  'وعلينا',
#  'أوعليكم',
#  'ولعلينا',
#  'ولعليكم',
#  'ألعليها',
#  'أوعليك',
#  'ولعلى',
#  'فعليكن',
#  'فعليهن',
#  'لعليهن',
#  'فعليها',
#  'وعليكما',
#  'عليهن',
#  'لعلى',
#  'أولعلي',
#  'عليها',
#  'أوعليكما',
#  'أولعلينا',
#  'أفعليكم',
#  'أوعليهم',
#  'وعليك',
#  'فعليه',
#  'ولعليك',
#  'لعليهما',
#  'أوعليهما',
#  'فلعليهم',
#  'ولعليكن',
#  'ألعليهما',
#  'لعليهم',
#  'أفعليك',
#  'أوعليهن',
#  'أعلي',
#  'فلعليكن',
#  'ولعليكما',
#  'عليهما',
#  'أفلعلي',
#  'عليك',
#  'على',
#  'فلعليكم',
#  'فعليكم',
#  'علينا',
#  'فعلينا',
#  'أفعليه',
#  'ألعليك',
#  'أعلينا',
#  'ألعليهم',
#  'فعليك',
#  'لعلينا',
#  'أولعليه',
#  'أفلعلينا',
#  'ألعليكما',
#  'أوعلى',
#  'علي']

# %%
len(stp.stopword_forms(u"على"))
# Out:
# 144

# %%
SW  = ['on','at','with','the','by','to','this','my']

T = 'I went to the university by bus On this monday with My friend at 9:00'

' '.join([i for i in T.split() if  not i.lower() in SW])
# Out:
# 'I went university bus monday friend 9:00'
