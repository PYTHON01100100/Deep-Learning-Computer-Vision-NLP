# %% [markdown]
# # GSDMM Code for Text Analysis

# %%
pip install git+https://github.com/rwalk/gsdmm.git
# Out:
# Collecting git+https://github.com/rwalk/gsdmm.git
#   Cloning https://github.com/rwalk/gsdmm.git to /tmp/pip-req-build-p8smkd8g
#   Running command git clone --filter=blob:none --quiet https://github.com/rwalk/gsdmm.git /tmp/pip-req-build-p8smkd8g
#   Resolved https://github.com/rwalk/gsdmm.git to commit 4ad1b6b6976743681ee4976b4573463d359214ee
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gsdmm==0.1) (1.23.5)

# %%
import numpy as np
import pandas as pd
from gsdmm import MovieGroupProcess

from gensim.utils import simple_preprocess
import gensim, spacy,re,os,nltk,random

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])


data = pd.read_csv(r'/content/drive/MyDrive/Data/Course/Corona.csv',header = 0, encoding = 'cp437')
data = data[::100]

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))


def make_n_grams(texts):
    bigram = gensim.models.Phrases(texts, min_count=5, threshold=100)
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram = gensim.models.Phrases(bigram[texts], threshold=100)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    bigrams_text = [bigram_mod[doc] for doc in texts]
    trigrams_text =  [trigram_mod[bigram_mod[doc]] for doc in bigrams_text]
    return trigrams_text




def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in gensim.parsing.preprocessing.STOPWORDS] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out
def top_words(mgp,cluster_word_distribution, top_cluster, values):
  Text = ''
  TheseResults = []
  for cluster in top_cluster:
    sort_dicts =sorted(mgp.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
    Text+= "\nCluster %s : %s"%(cluster,sort_dicts)
    TheseResults.append([cluster,sort_dicts])
  return Text,TheseResults

tokens_reviews = list(sent_to_words(data['OriginalTweet']))
tokens_reviews = make_n_grams(tokens_reviews)
reviews_lemmatized = lemmatization(tokens_reviews, allowed_postags=['NOUN', 'VERB', 'ADV'])
reviews_lemmatized = remove_stopwords(reviews_lemmatized)
print(reviews_lemmatized)
# np.random.seed(0)
Results =[]
X = 0
K = 5
for Alpha in list(np.linspace(0.05,1,5)) :  # using different values for alpha
  for Beta in list(np.linspace(0.05,1,5)) : # using different values for beta
    X+=1
    print(f'Phase Number {X}')
    mgp = MovieGroupProcess(K=K, alpha=Alpha, beta=Beta, n_iters=5)
    vocab = set(x for review in reviews_lemmatized for x in review)
    n_terms = len(vocab)
    model = mgp.fit(reviews_lemmatized, n_terms)
    doc_count = np.array(mgp.cluster_doc_count)
    top_index = doc_count.argsort()[-10:][::-1]
    Loss =0
    for i in range(K) :
      Loss += abs((1/K)-(doc_count[i]/sum(doc_count)))
    Results.append({'Parameters' : [Alpha,Beta],
                    'Loss':Loss,
                    'Doc Number':doc_count,
                    'Top Index':doc_count.argsort()[-10:][::-1],
                    'Top Words' : top_words(mgp,mgp.cluster_word_distribution, top_index, 10)[0],
                    'All Words' : top_words(mgp,mgp.cluster_word_distribution, top_index, 100)[1]})


ResultsDF = pd.DataFrame(columns = ['Parameters', 'Loss', 'Doc Number', 'Top Index', 'Top Words', 'All Words'])
for n,i in enumerate(Results) :
  ResultsDF.loc[n] = list(i.values())
ResultsDF
TotalCluster = [f'Cluster {i}' for i in range(K)]
for j in TotalCluster :
  ResultsDF[j] =ResultsDF['Top Words'].apply(lambda x : [i for i in str(x.strip('\n')).split('\n') if j in i][0].strip(f'{j} : ').strip('[]'))

for j in range(K) :
  ResultsDF[f'All Cluster {j}'] = ResultsDF['All Words'].apply(lambda x : [i[1] for i in x if i[0]==j])
# if not os.path.exists(os.path.join(MainPath,SelectedData,'01 GSDMMFiles')) :  os.makedirs(os.path.join(MainPath,SelectedData,'01 GSDMMFiles'))
ResultsDF.to_csv('1.csv')  # saving in 01 folder
Results
# Out:
# [[], ['hate', 'grocery', 'shopping', 'swear', 'online', 'shop', 'deal', 'swathe', 'panic', 'buyer', 'panicbuyinguk', 'moron'], ['drsanjaygupta', 'johnberman', 'newday', 'business', 'trump', 'tout', 'supply', 'online', 'order', 'supply', 'avail', 'need', 'help', 'arena', 'supply'], ['prisoner', 'release', 'view', 'coronavirus', 'prisoner', 'create', 'burn', 'prison', 'cell', 'news', 'suspect', 'covid', 'prison', 'prisoner', 'face', 'mask', 'amp', 'sell', 'extremely', 'price', 'bharat'], ['provider', 'feel', 'consumer', 'feel', 'seek', 'advice', 'attention', 'consumer', 'ihss', 'worker', 'work'], ['ære', 'community', 'ære', 'stay', 'home', 'stay'], ['thank', 'grocery_store', 'employee', 'farmer', 'trucker', 'healthcare', 'worker', 'employee', 'work', 'individual', 'offer', 'life', 'help', 'fight'], ['dtc', 'ecommerce', 'people', 'stay', 'home', 'fear', 'coronavirus', 'spread', 'amp', 'demand', 'pickup', 'delivery', 'accelerate', 'grocery', 'hit', 'sale', 'forecast', 'hit'], ['agree', 'avoid', 'horde', 'food', 'necessity', 'shelf', 'grocery_store', 'trigger', 'mind', 'person', 'disability', 'car', 'limit', 'buy', 'carry', 'carry', 'day', 'food'], ['gamestop', 'store', 'coronavirus'], ['people', 'thing', 'need', 'mention', 'work', 'chain', 'right', 'push', 'limit', 'triple', 'normally', 'sale'], ['price', 'bit', 'afford', 'surrender', 'fate', 'excuse', 'price', 'rise', 'know', 'measure', 'enforce', 'minute', 'count', 'thank'], ['quarenteen', 'coronavirus', 've', 'lower', 'ebook', 'price', 'cent', 'amazon', 'need', 'fantasy', 'novel', 'company', 've', 'cover'], ['suppose', 'want', 'reduce', 'price', 'sky', 'store', 'movie', 'help', 'monster', 'entertain'], ['perception', 'panic', 'report', 'reality', 'grocerystore', 'coronaviru', 'nytime', 'qauhv'], ['thank', 'people', 'work', 'frontline', 'work', 'home', 'healthcare', 'worker', 'delivery', 'people', 'pharmacy', 'coronavirus'], ['tissue', 'paper', 'fish', 'bread', 'supply', 'supermarket', 'day', 'enhance', 'community', 'quarantine', 'luzon', 'control', 'spread'], ['affect', 'coronavirus', 'mean', 'lossofjob', 'gotsick', 'family', 'member', 'affect', 'payment', 'struggle', 'mean', 'creditor', 'credit', 'consumer'], ['meet', 'lady', 'today', 'bleach', 'bottle', 'panic', 'buying', 'tell', 'religion', 'require', 'thing', 'panicbuye'], ['store', 'work', 'submit', 'request', 'remain', 'restriction', 'ceo', 'coddle', 'home', 'face', 'face', 'public', 'possibly', 'catch', 'infect', 'father', 'kill'], ['kill', 'mother', 'fucker', 'panic', 'buy', 'access', 'food', 'water'], ['need', 'stock', 'freezer', 'meal', 'buzzfeedfood', 'idea', 'include'], ['monitor', 'rapidly', 'evolve', 'situation', 'decision', 'close', 'store', 'location', 'start', 'week', 'situation', 'change', 'plan', 'change', 'post'], ['want', 'house', 'clean', 'need', 'spend', 'supermarket', 'clean', 'product', 'video', 'link', 'want', 'know'], ['authority', 'urgently', 'ensure', 'planning', 'control', 'food', 'delivery', 'retailer', 'distributor', 'freight', 'industry', 'disruption', 'cause', 'coronavirus'], ['step', 'pandemic', 'cancel', 'event', 'notice', 'lower', 'price', 'course', 'practice', 'whm', 'safely', 'home', 'boost', 'immunity', 'https', 'uaz'], ['let', 'mom', 'shopping', 'cyberbullye', 'people', 'facebook', 'covid', 'virus', 'hero', 'maybe', 'bitch'], ['severity', 'outbreak', 'safety', 'value', 'customer', 'employee', 'close', 'ashba', 'clothing', 'store', 'locate', 'day'], ['illustrate', 'economy', 'drive', 'labor', 'consumer', 'demand', 'job', 'creator', 'term', 'capital', 'holder', 'currently', 'use', 'try', 'sanitize', 'image'], ['scammer', 'prey', 'people', 'situation', 'contact', 'offer', 'recover', 'money', 'event', 'holiday', 'look', 'sign', 'potential'], ['protect', 'grocery', 'shop', 'consumer', 'report', 'nobpubxujf', 'caregive', 'eldercare'], ['report', 'government', 'soon', 'send', 'money', 'check', 'deposit', 'work', 'share', 'thing', 'know', 'avoid'], ['plan', 'trip', 'supermarket', 'week', 'time', ...
# Phase Number 1
# In stage 0: transferred 253 clusters with 5 clusters populated
# In stage 1: transferred 136 clusters with 5 clusters populated
# In stage 2: transferred 87 clusters with 5 clusters populated
# In stage 3: transferred 65 clusters with 5 clusters populated
# In stage 4: transferred 63 clusters with 5 clusters populated
# Phase Number 2
# In stage 0: transferred 293 clusters with 5 clusters populated
# In stage 1: transferred 147 clusters with 5 clusters populated
# In stage 2: transferred 120 clusters with 5 clusters populated
# In stage 3: transferred 91 clusters with 5 clusters populated
# In stage 4: transferred 87 clusters with 5 clusters populated
# Phase Number 3
# In stage 0: transferred 280 clusters with 5 clusters populated
# In stage 1: transferred 190 clusters with 5 clusters populated
# In stage 2: transferred 141 clusters with 5 clusters populated
# In stage 3: transferred 98 clusters with 5 clusters populated
# In stage 4: transferred 88 clusters with 5 clusters populated
# Phase Number 4
# In stage 0: transferred 293 clusters with 5 clusters populated
# In stage 1: transferred 181 clusters with 5 clusters populated
# In stage 2: transferred 147 clusters with 5 clusters populated
# In stage 3: transferred 118 clusters with 5 clusters populated
# In stage 4: transferred 99 clusters with 5 clusters populated
# Phase Number 5
# In stage 0: transferred 301 clusters with 5 clusters populated
# In stage 1: transferred 190 clusters with 5 clusters populated
# In stage 2: transferred 124 clusters with 5 clusters populated
# In stage 3: transferred 78 clusters with 4 clusters populated
# In stage 4: transferred 61 clusters with 3 clusters populated
# Phase Number 6
# In stage 0: transferred 271 clusters with 5 clusters populated
# In stage 1: transferred 139 clusters with 5 clusters populated
# In stage 2: transferred 100 clusters with 5 clusters populated
# In stage 3: transferred 83 clusters with 5 clusters populated
# In stage 4: transferred 75 clusters with 5 clusters populated
# Phase Number 7
# In stage 0: transferred 286 clusters with 5 clusters populated
# In stage 1: transferred 164 clusters with 5 clusters populated
# In stage 2: transferred 104 clusters with 5 clusters populated
# In stage 3: transferred 99 clusters with 5 clusters populated
# In stage 4: transferred 101 clusters with 5 clusters populated
# Phase Number 8
# In stage 0: transferred 287 clusters with 5 clusters populated
# In stage 1: transferred 192 clusters with 5 clusters populated
# In stage 2: transferred 150 clusters with 5 clusters populated
# In stage 3: transferred 112 clusters with 5 clusters populated
# In stage 4: transferred 107 clusters with 5 clusters populated
# Phase Number 9
# In stage 0: transferred 287 clusters with 5 clusters populated
# In stage 1: transferred 178 clusters with 5 clusters populated
# In stage 2: transferred 150 clusters with 5 clusters populated
# In stage 3: transferred 122 clusters with 5 clusters populated
# In stage 4: transferred 105 clusters with 5 clusters populated
# Phase Number 10
# In stage 0: transferred 298 clusters with 5 clusters populated
# In stage 1: transferred 176 clusters with 5 clusters populated
# In stage 2: transferred 104 clusters with 5 clusters populated
# In stage 3: transferred 71 clusters with 5 clusters populated
# In stage 4: transferred 61 clusters with 5 clusters populated
# Phase Number 11
# In stage 0: transferred 275 clusters with 5 clusters populated
# In stage 1: transferred 144 clusters with 5 clusters populated
# In stage 2: transferred 78 clusters with 5 clusters populated
# In stage 3: transferred 63 clusters with 5 clusters populated
# In stage 4: transferred 61 clusters with 5 clusters populated
# Phase Number 12
# In stage 0: transferred 281 clusters with 5 clusters populated
# In stage 1: transferred 176 clusters with 5 clusters populated
# In stage 2: transferred 133 clusters with 5 clusters populated
# In stage 3: transferred 89 clusters with 5 clusters populated
# In stage 4: transferred 109 clusters with 5 clusters populated
# Phase Number 13
# In stage 0: transferred 272 clusters with 5 clusters populated
# In stage 1: transferred 149 clusters with 5 clusters populated
# In stage 2: transferred 138 clusters with 5 clusters populated
# In stage 3: transferred 136 clusters with 5 clusters populated
# In stage 4: transferred 110 clusters with 5 clusters populated
# Phase Number 14
# In stage 0: transferred 282 clusters with 5 clusters populated
# In stage 1: transferred 176 clusters with 5 clusters populated
# In stage 2: transferred 139 clusters with 5 clusters populated
# In stage 3: transferred 122 clusters with 5 clusters populated
# In stage 4: transferred 91 clusters with 5 clusters populated
# Phase Number 15
# In stage 0: transferred 296 clusters with 5 clusters populated
# In stage 1: transferred 208 clusters with 5 clusters populated
# In stage 2: transferred 150 clusters with 5 clusters populated
# In stage 3: transferred 110 clusters with 5 clusters populated
# In stage 4: transferred 91 clusters with 5 clusters populated
# Phase Number 16
# In stage 0: transferred 255 clusters with 5 clusters populated
# In stage 1: transferred 124 clusters with 5 clusters populated
# In stage 2: transferred 99 clusters with 5 clusters populated
# In stage 3: transferred 77 clusters with 5 clusters populated
# In stage 4: transferred 60 clusters with 5 clusters populated
# Phase Number 17
# In stage 0: transferred 279 clusters with 5 clusters populated
# In stage 1: transferred 166 clusters with 5 clusters populated
# In stage 2: transferred 122 clusters with 5 clusters populated
# In stage 3: transferred 108 clusters with 5 clusters populated
# In stage 4: transferred 80 clusters with 5 clusters populated
# Phase Number 18
# In stage 0: transferred 284 clusters with 5 clusters populated
# In stage 1: transferred 174 clusters with 5 clusters populated
# In stage 2: transferred 144 clusters with 5 clusters populated
# In stage 3: transferred 121 clusters with 5 clusters populated
# In stage 4: transferred 86 clusters with 5 clusters populated
# Phase Number 19
# In stage 0: transferred 298 clusters with 5 clusters populated
# In stage 1: transferred 212 clusters with 5 clusters populated
# In stage 2: transferred 150 clusters with 5 clusters populated
# In stage 3: transferred 125 clusters with 5 clusters populated
# In stage 4: transferred 97 clusters with 5 clusters populated
# Phase Number 20
# In stage 0: transferred 298 clusters with 5 clusters populated
# In stage 1: transferred 204 clusters with 5 clusters populated
# In stage 2: transferred 146 clusters with 5 clusters populated
# In stage 3: transferred 129 clusters with 5 clusters populated
# In stage 4: transferred 141 clusters with 4 clusters populated
# Phase Number 21
# In stage 0: transferred 276 clusters with 5 clusters populated
# In stage 1: transferred 139 clusters with 5 clusters populated
# In stage 2: transferred 86 clusters with 5 clusters populated
# In stage 3: transferred 63 clusters with 5 clusters populated
# In stage 4: transferred 56 clusters with 5 clusters populated
# Phase Number 22
# In stage 0: transferred 269 clusters with 5 clusters populated
# In stage 1: transferred 159 clusters with 5 clusters populated
# In stage 2: transferred 124 clusters with 5 clusters populated
# In stage 3: transferred 98 clusters with 5 clusters populated
# In stage 4: transferred 92 clusters with 5 clusters populated
# Phase Number 23
# In stage 0: transferred 285 clusters with 5 clusters populated
# In stage 1: transferred 190 clusters with 5 clusters populated
# In stage 2: transferred 128 clusters with 5 clusters populated
# In stage 3: transferred 94 clusters with 5 clusters populated
# In stage 4: transferred 106 clusters with 5 clusters populated
# Phase Number 24
# In stage 0: transferred 298 clusters with 5 clusters populated
# In stage 1: transferred 197 clusters with 5 clusters populated
# In stage 2: transferred 146 clusters with 5 clusters populated
# In stage 3: transferred 128 clusters with 5 clusters populated
# In stage 4: transferred 93 clusters with 5 clusters populated
# Phase Number 25
# In stage 0: transferred 291 clusters with 5 clusters populated
# In stage 1: transferred 176 clusters with 5 clusters populated
# In stage 2: transferred 117 clusters with 5 clusters populated
# In stage 3: transferred 117 clusters with 4 clusters populated
# In stage 4: transferred 99 clusters with 3 clusters populated
# [{'Parameters': [0.05, 0.05],
#   'Loss': 0.11262135922330099,
#   'Doc Number': array([81, 93, 66, 77, 95]),
#   'Top Index': array([4, 1, 0, 3, 2]),
#   'Top Words': "\nCluster 4 : [('consumer', 31), ('coronavirus', 30), ('food', 28), ('price', 25), ('business', 12), ('report', 12), ('store', 12), ('worker', 12), ('amp', 12), ('supply', 11)]\nCluster 1 : [('supermarket', 27), ('worker', 27), ('grocery_store', 17), ('food', 14), ('work', 14), ('staff', 14), ('coronavirus', 13), ('covid', 13), ('employee', 10), ('people', 9)]\nCluster 0 : [('price', 21), ('coronavirus', 21), ('covid', 13), ('people', 12), ('toiletpaper', 11), ('panic', 10), ('use', 9), ('oil', 8), ('shop', 7), ('supermarket', 7)]\nCluster 3 : [('coronavirus', 23), ('consumer', 22), ('price', 20), ('oil', 14), ('demand', 12), ('change', 12), ('food', 11), ('need', 11), ('supermarket', 10), ('covid', 9)]\nCluster 2 : [('price', 14), ('food', 14), ('coronavirus', 13), ('people', 13), ('supermarket', 13), ('stock', 8), ('covid', 8), ('toiletpaper', 7), ('work', 6), ('run', 6)]",
#   'All Words': [[4,
#     [('consumer', 31),
#      ('coronavirus', 30),
#      ('food', 28),
#      ('price', 25),
#      ('business', 12),
#      ('report', 12),
#      ('store', 12),
#      ('worker', 12),
#      ('amp', 12),
#      ('supply', 11),
#      ('people', 11),
#      ('grocery', 10),
#      ('demand', 10),
#      ('pay', 8),
#      ('help', 8),
#      ('covid', 7),
#      ('impact', 7),
#      ('service', 7),
#      ('delivery', 7),
#      ('stock', 7),
#      ('shop', 6),
#      ('buy', 6),
#      ('share', 6),
#      ('crisis', 6),
#      ('hike', 6),
#      ('increase', 6),
#      ('home', 5),
#      ('information', 5),
#      ('health', 5),
#      ('know', 5),
#      ('risk', 5),
#      ('protection', 5),
#      ('bank', 5),
#      ('relate', 5),
#      ('good', 5),
#      ('retailer', 5),
#      ('chain', 5),
#      ('industry', 5),
#      ('trump', 4),
#      ('panic', 4),
#      ('let', 4),
#      ('outbreak', 4),
#      ('provide', 4),
#      ('employee', 4),
#      ('grocery_store', 4),
#      ('thank', 4),
#      ('read', 4),
#      ('ecommerce', 4),
#      ('deliver', 4),
#      ('emergency', 4),
#      ('purchase', 4),
#      ('thought', 4),
#      ('panicbuye', 4),
#      ('run', 4),
#      ('limit', 4),
#      ('hope', 4),
#      ('product', 4),
#      ('work', 4),
#      ('need', 3),
#      ('buying', 3),
#      ('thing', 3),
#      ('facebook', 3),
#      ('bitch', 3),
#      ('supermarket', 3),
#      ('time', 3),
#      ('analyst', 3),
#      ('try', 3),
#      ('sell', 3),
#      ('watch', 3),
#      ('sale', 3),
#      ('change', 3),
#      ('ramp', 3),
#      ('send', 3),
#      ('use', 3),
#      ('profiteer', 3),
#      ('pick', 3),
#      ('restaurant', 3),
#      ('explain', 3),
#      ('review', 3),
#      ('anticipate', 3),
#      ('right', 3),
#      ('world', 3),
#      ('check', 3),
#      ('case', 3),
#      ('receive', 3),
#      ('lay', 3),
#      ('hit', 3),
#      ('day', 3),
#      ('speak', 3),
#      ('adapt', 3),
#      ('reduce', 3),
#      ('shortage', 3),
#      ('contact', 3),
#      ('egg', 3),
#      ('surge', 3),
#      ('website', 3),
#      ('closure', 3),
#      ('price_gouge', 3),
#      ('jack', 3),
#      ('drive', 3)]],
#    [1,
#     [('supermarket', 27),
#      ('worker', 27),
#      ('grocery_store', 17),
#      ('food', 14),
#      ('work', 14),
#      ('staff', 14),
#      ('coronavirus', 13),
#      ('covid', 13),
#      ('employee', 10),
#      ('people', 9),
#      ('time', 9),
#      ('help', 9),
#      ('spread', 8),
#      ('consumer', 8),
#      ('line', 8),
#      ('home', 7),
#      ('avoid', 7),
#      ('follow', 7),
#      ('use', 7),
#      ('customer', 7),
#      ('healthcare', 7),
#      ('thank', 7),
#      ('delivery', 6),
#      ('week', 6),
#      ('hand', 6),
#      ('feel', 6),
#      ('stay', 5),
#      ('amp', 5),
#      ('shelf', 5),
#      ('today', 5),
#      ('wash', 5),
#      ('nurse', 5),
#      ('sanitizer', 5),
#      ('social_distance', 5),
#      ('let', 5),
#      ('family', 5),
#      ('hour', 5),
#      ('right', 5),
#      ('wait', 5),
#      ('service', 5),
#      ('provide', 5),
#      ('ære', 4),
#      ('community', 4),
#      ('demand', 4),
#      ('tissue', 4),
#      ('store', 4),
#      ('distance', 4),
#      ('member', 4),
#      ('support', 4),
#      ('mean', 4),
#      ('protect', 4),
#      ('thing', 4),
#      ('place', 4),
#      ('continue', 4),
#      ('public', 4),
#      ('risk', 4),
#      ('hospital', 4),
#      ('fight', 4),
#      ('soap', 4),
#      ('asda', 4),
#      ('nursing', 4),
#      ('doctor', 4),
#      ('shop', 4),
#      ('supply', 3),
#      ('start', 3),
#      ('deliver', 3),
#      ('https', 3),
#      ('need', 3),
#      ('base', 3),
#      ('credit', 3),
#      ('consider', 3),
#      ('happen', 3),
#      ('pharmacy', 3),
#      ('life', 3),
#      ('practice', 3),
#      ('tell', 3),
#      ('folk', 3),
#      ('stock', 3),
#      ('team', 3),
#      ('price_gouge', 3),
#      ('chain', 3),
#      ('process', 3),
#      ('state', 3),
#      ('look', 3),
#      ('appreciate', 3),
#      ('tesco', 3),
#      ('frontline', 3),
#      ('nhs', 3),
#      ('want', 3),
#      ('trade', 3),
#      ('pantry', 3),
#      ('sneeze', 3),
#      ('alcohol', 3),
#      ('hero', 3),
#      ('advice', 3),
#      ('enforce', 3),
#      ('resource', 3),
#      ('plan', 3),
#      ('man', 3),
#      ('provider', 3)]],
#    [0,
#     [('price', 21),
#      ('coronavirus', 21),
#      ('covid', 13),
#      ('people', 12),
#      ('toiletpaper', 11),
#      ('panic', 10),
#      ('use', 9),
#      ('oil', 8),
#      ('shop', 7),
#      ('supermarket', 7),
#      ('home', 7),
#      ('consumer', 7),
#      ('buy', 7),
#      ('business', 7),
#      ('think', 7),
#      ('help', 6),
#      ('food', 6),
#      ('store', 6),
#      ('travel', 6),
#      ('face', 6),
#      ('order', 6),
#      ('mask', 6),
#      ('sanitizer', 6),
#      ('offer', 5),
#      ('crisis', 5),
#      ('break', 5),
#      ('company', 5),
#      ('win', 5),
#      ('chicken', 5),
#      ('hand', 5),
#      ('product', 4),
#      ('try', 4),
#      ('thing', 4),
#      ('support', 4),
#      ('gas', 4),
#      ('leave', 4),
#      ('situation', 4),
#      ('kill', 4),
#      ('country', 4),
#      ('spread', 4),
#      ('wipe', 4),
#      ('war', 4),
#      ('look', 4),
#      ('health', 4),
#      ('catch', 4),
#      ('grocery', 3),
#      ('shopping', 3),
#      ('economy', 3),
#      ('demand', 3),
#      ('term', 3),
#      ('come', 3),
#      ('state', 3),
#      ('hope', 3),
#      ('run', 3),
#      ('month', 3),
#      ('announce', 3),
#      ('loan', 3),
#      ('payment', 3),
#      ('place', 3),
#      ('bank', 3),
#      ('holiday', 3),
#      ('end', 3),
#      ('produce', 3),
#      ('impact', 3),
#      ('buyer', 3),
#      ('infect', 3),
#      ('follow', 3),
#      ('contact', 3),
#      ('virus', 3),
#      ('suspend', 3),
#      ('eat', 3),
#      ('hand_sanitizer', 3),
#      ('life', 3),
#      ('public', 3),
#      ('trip', 3),
#      ('ask', 3),
#      ('coronacrisis', 3),
#      ('gold', 3),
#      ('grocery_store', 2),
#      ('work', 2),
#      ('holder', 2),
#      ('change', 2),
#      ('year', 2),
#      ('risk', 2),
#      ('election', 2),
#      ('vaccine', 2),
#      ('assistance', 2),
#      ('fee', 2),
#      ('afternoon', 2),
#      ('instagram', 2),
#      ('pharmacy', 2),
#      ('delivery', 2),
#      ('insight', 2),
#      ('kind', 2),
#      ('learn', 2),
#      ('package', 2),
#      ('prey', 2),
#      ('scammer', 2),
#      ('decline', 2),
#      ('parent', 2)]],
#    [3,
#     [('coronavirus', 23),
#      ('consumer', 22),
#      ('price', 20),
#      ('oil', 14),
#      ('demand', 12),
#      ('change', 12),
#      ('food', 11),
#      ('need', 11),
#      ('supermarket', 10),
#      ('covid', 9),
#      ('shop', 9),
#      ('fall', 9),
#      ('home', 8),
#      ('store', 8),
#      ('time', 8),
#      ('https', 8),
#      ('week', 7),
#      ('face', 6),
#      ('close', 6),
#      ('day', 6),
#      ('video', 6),
#      ('product', 6),
#      ('stay', 6),
#      ('shopping', 5),
#      ('know', 5),
#      ('business', 5),
#      ('market', 5),
#      ('post', 5),
#      ('support', 5),
#      ('industry', 5),
#      ('amp', 4),
#      ('outbreak', 4),
#      ('cook', 4),
#      ('hour', 4),
#      ('start', 4),
#      ('scam', 4),
#      ('blog', 4),
#      ('want', 4),
#      ('medium', 4),
#      ('item', 4),
#      ('pay', 4),
#      ('online', 4),
#      ('spend', 4),
#      ('rise', 4),
#      ('situation', 4),
#      ('money', 4),
#      ('mask', 3),
#      ('feel', 3),
#      ('customer', 3),
#      ('employee', 3),
#      ('learn', 3),
#      ('remember', 3),
#      ('virus', 3),
#      ('trend', 3),
#      ('gas', 3),
#      ('report', 3),
#      ('choice', 3),
#      ('open', 3),
#      ('expert', 3),
#      ('hit', 3),
#      ('tv', 3),
#      ('world', 3),
#      ('watch', 3),
#      ('hospital', 3),
#      ('household', 3),
#      ('read', 3),
#      ('like', 3),
#      ('profit', 3),
#      ('temporarily', 3),
#      ('ve', 3),
#      ('news', 3),
#      ('sell', 3),
#      ('confidence', 3),
#      ('behaviour', 3),
#      ('line', 3),
#      ('event', 3),
#      ('economy', 3),
#      ('prisoner', 3),
#      ('work', 2),
#      ('people', 2),
#      ('level', 2),
#      ('grocery_store', 2),
#      ('hand', 2),
#      ('chain', 2),
#      ('health', 2),
#      ('toiletpaper', 2),
#      ('decision', 2),
#      ('house', 2),
#      ('heb', 2),
#      ('cut', 2),
#      ('retailer', 2),
#      ('rule', 2),
#      ('allow', 2),
#      ('period', 2),
#      ('join', 2),
#      ('discussion', 2),
#      ('surround', 2),
#      ('shift', 2),
#      ('message', 2),
#      ('early', 2)]],
#    [2,
#     [('price', 14),
#      ('food', 14),
#      ('coronavirus', 13),
#      ('people', 13),
#      ('supermarket', 13),
#      ('stock', 8),
#      ('covid', 8),
#      ('toiletpaper', 7),
#      ('work', 6),
#      ('run', 6),
#      ('case', 6),
#      ('milk', 6),
#      ('thing', 5),
#      ('need', 5),
#      ('market', 5),
#      ('demand', 5),
#      ('look', 5),
#      ('today', 5),
#      ('meal', 5),
#      ('day', 5),
#      ('pay', 4),
#      ('time', 4),
#      ('love', 4),
#      ('place', 4),
#      ('week', 4),
#      ('happen', 4),
#      ('change', 4),
#      ('panic', 4),
#      ('number', 4),
#      ('income', 4),
#      ('ensure', 4),
#      ('avoid', 4),
#      ('family', 4),
#      ('store', 3),
#      ('sale', 3),
#      ('know', 3),
#      ('cause', 3),
#      ('grocery_store', 3),
#      ('update', 3),
#      ('distance', 3),
#      ('study', 3),
#      ('buying', 3),
#      ('ask', 3),
#      ('government', 3),
#      ('lockdown', 3),
#      ('lose', 3),
#      ('crash', 3),
#      ('tell', 3),
#      ('cover', 3),
#      ('travel', 3),
#      ('start', 3),
#      ('site', 3),
#      ('job', 3),
#      ('force', 3),
#      ('relief', 3),
#      ('check', 3),
#      ('team', 3),
#      ('way', 3),
#      ('send', 3),
#      ('live', 3),
#      ('box', 3),
#      ('shortage', 3),
#      ('reduce', 3),
#      ('stophoarde', 3),
#      ('hoard', 3),
#      ('shilla', 3),
#      ('chain', 2),
#      ('rise', 2),
#      ('control', 2),
#      ('crisis', 2),
#      ('virus', 2),
#      ('buy', 2),
#      ('report', 2),
#      ('shop', 2),
#      ('floor', 2),
#      ('amp', 2),
#      ('follow', 2),
#      ('remember', 2),
#      ('counter', 2),
#      ('meet', 2),
#      ('country', 2),
#      ('half', 2),
#      ('patient', 2),
#      ('gold', 2),
#      ('month', 2),
#      ('rent', 2),
#      ('drug', 2),
#      ('peak', 2),
#      ('care', 2),
#      ('uk', 2),
#      ('confront', 2),
#      ('city', 2),
#      ('turn', 2),
#      ('afford', 2),
#      ('focus', 2),
#      ('watch', 2),
#      ('especially', 2),
#      ('idea', 2),
#      ('issue', 2),
#      ('matter', 2)]]]},
#  {'Parameters': [0.05, 0.2875],
#   'Loss': 0.15145631067961163,
#   'Doc Number': array([ 65, 113,  83,  75,  76]),
#   'Top Index': array([1, 2, 4, 3, 0]),
#   'Top Words': "\nCluster 1 : [('supermarket', 30), ('coronavirus', 27), ('worker', 26), ('food', 23), ('covid', 20), ('grocery_store', 17), ('people', 17), ('work', 13), ('home', 13), ('store', 13)]\nCluster 2 : [('food', 31), ('coronavirus', 30), ('price', 27), ('consumer', 17), ('people', 16), ('demand', 14), ('product', 11), ('report', 11), ('stock', 11), ('buy', 11)]\nCluster 4 : [('price', 20), ('consumer', 14), ('covid', 13), ('week', 13), ('store', 11), ('coronavirus', 8), ('change', 8), ('time', 7), ('supermarket', 7), ('toiletpaper', 7)]\nCluster 3 : [('consumer', 32), ('supermarket', 18), ('business', 15), ('worker', 12), ('help', 11), ('food', 11), ('coronavirus', 10), ('need', 10), ('risk', 10), ('supply', 9)]\nCluster 0 : [('price', 32), ('coronavirus', 25), ('oil', 22), ('demand', 9), ('fall', 9), ('hand', 8), ('food', 7), ('economy', 7), ('consumer', 6), ('wash', 6)]",
#   'All Words': [[1,
#     [('supermarket', 30),
#      ('coronavirus', 27),
#      ('worker', 26),
#      ('food', 23),
#      ('covid', 20),
#      ('grocery_store', 17),
#      ('people', 17),
#      ('work', 13),
#      ('home', 13),
#      ('store', 13),
#      ('panic', 12),
#      ('toiletpaper', 12),
#      ('shop', 11),
#      ('employee', 10),
#      ('time', 10),
#      ('day', 9),
#      ('grocery', 8),
#      ('thank', 7),
#      ('help', 7),
#      ('customer', 7),
#      ('run', 7),
#      ('shelf', 7),
#      ('line', 7),
#      ('delivery', 7),
#      ('staff', 7),
#      ('stay', 7),
#      ('know', 7),
#      ('amp', 6),
#      ('healthcare', 6),
#      ('public', 6),
#      ('spread', 6),
#      ('today', 6),
#      ('tell', 6),
#      ('place', 6),
#      ('family', 6),
#      ('feel', 6),
#      ('fight', 5),
#      ('need', 5),
#      ('nurse', 5),
#      ('service', 5),
#      ('follow', 5),
#      ('deliver', 5),
#      ('test', 5),
#      ('man', 5),
#      ('shopping', 5),
#      ('coronaviru', 5),
#      ('chain', 5),
#      ('buying', 5),
#      ('avoid', 5),
#      ('https', 4),
#      ('hour', 4),
#      ('fear', 4),
#      ('demand', 4),
#      ('item', 4),
#      ('try', 4),
#      ('hero', 4),
#      ('right', 4),
#      ('walk', 4),
#      ('wipe', 4),
#      ('ask', 4),
#      ('pharmacy', 4),
#      ('doctor', 4),
#      ('distance', 4),
#      ('couple', 4),
#      ('close', 4),
#      ('wait', 4),
#      ('thing', 4),
#      ('way', 4),
#      ('spend', 4),
#      ('cook', 4),
#      ('hit', 4),
#      ('virus', 4),
#      ('chicken', 4),
#      ('look', 3),
#      ('driver', 3),
#      ('catch', 3),
#      ('buy', 3),
#      ('serve', 3),
#      ('folk', 3),
#      ('provide', 3),
#      ('appreciate', 3),
#      ('allow', 3),
#      ('restaurant', 3),
#      ('pickup', 3),
#      ('assistant', 3),
#      ('ære', 3),
#      ('consider', 3),
#      ('start', 3),
#      ('coronacrisis', 3),
#      ('floor', 3),
#      ('continue', 3),
#      ('car', 3),
#      ('ensure', 3),
#      ('love', 3),
#      ('infect', 3),
#      ('location', 3),
#      ('ruin', 3),
#      ('open', 3),
#      ('use', 3),
#      ('limit', 3)]],
#    [2,
#     [('food', 31),
#      ('coronavirus', 30),
#      ('price', 27),
#      ('consumer', 17),
#      ('people', 16),
#      ('demand', 14),
#      ('product', 11),
#      ('report', 11),
#      ('stock', 11),
#      ('buy', 11),
#      ('case', 9),
#      ('covid', 9),
#      ('shop', 8),
#      ('increase', 8),
#      ('share', 7),
#      ('sanitizer', 7),
#      ('home', 6),
#      ('amp', 6),
#      ('service', 6),
#      ('use', 6),
#      ('emergency', 6),
#      ('hike', 6),
#      ('run', 6),
#      ('mask', 6),
#      ('panic', 5),
#      ('thing', 5),
#      ('hand', 5),
#      ('business', 5),
#      ('sell', 5),
#      ('happen', 5),
#      ('start', 4),
#      ('retailer', 4),
#      ('industry', 4),
#      ('health', 4),
#      ('purchase', 4),
#      ('time', 4),
#      ('hope', 4),
#      ('box', 4),
#      ('bank', 4),
#      ('meal', 4),
#      ('affect', 4),
#      ('company', 4),
#      ('state', 4),
#      ('supply', 4),
#      ('seller', 4),
#      ('face', 4),
#      ('try', 4),
#      ('price_gouge', 4),
#      ('household', 4),
#      ('profiteer', 4),
#      ('change', 4),
#      ('buyer', 3),
#      ('sale', 3),
#      ('work', 3),
#      ('week', 3),
#      ('ensure', 3),
#      ('offer', 3),
#      ('world', 3),
#      ('impact', 3),
#      ('market', 3),
#      ('mean', 3),
#      ('continue', 3),
#      ('access', 3),
#      ('crisis', 3),
#      ('ramp', 3),
#      ('study', 3),
#      ('anticipate', 3),
#      ('surge', 3),
#      ('thought', 3),
#      ('number', 3),
#      ('receive', 3),
#      ('read', 3),
#      ('claim', 3),
#      ('profit', 3),
#      ('watch', 3),
#      ('jack', 3),
#      ('shopping', 3),
#      ('rise', 3),
#      ('vaccine', 3),
#      ('die', 3),
#      ('store', 3),
#      ('let', 3),
#      ('gas', 3),
#      ('https', 3),
#      ('prisoner', 3),
#      ('community', 2),
#      ('cause', 2),
#      ('extremely', 2),
#      ('action', 2),
#      ('check', 2),
#      ('question', 2),
#      ('foodsecurity', 2),
#      ('coronavirusuk', 2),
#      ('suspend', 2),
#      ('brand', 2),
#      ('help', 2),
#      ('mind', 2),
#      ('gold', 2),
#      ('effort', 2),
#      ('article', 2)]],
#    [4,
#     [('price', 20),
#      ('consumer', 14),
#      ('covid', 13),
#      ('week', 13),
#      ('store', 11),
#      ('coronavirus', 8),
#      ('change', 8),
#      ('time', 7),
#      ('supermarket', 7),
#      ('toiletpaper', 7),
#      ('video', 7),
#      ('want', 6),
#      ('home', 6),
#      ('update', 6),
#      ('work', 5),
#      ('reduce', 5),
#      ('delivery', 5),
#      ('thing', 5),
#      ('pay', 5),
#      ('response', 5),
#      ('market', 5),
#      ('today', 5),
#      ('travel', 5),
#      ('impact', 5),
#      ('outbreak', 5),
#      ('order', 4),
#      ('grocery_store', 4),
#      ('kill', 4),
#      ('virus', 4),
#      ('send', 4),
#      ('know', 4),
#      ('look', 4),
#      ('face', 4),
#      ('milk', 4),
#      ('fight', 4),
#      ('watch', 4),
#      ('plan', 4),
#      ('use', 4),
#      ('cover', 4),
#      ('house', 4),
#      ('process', 4),
#      ('need', 3),
#      ('pharmacy', 3),
#      ('money', 3),
#      ('temporarily', 3),
#      ('hour', 3),
#      ('love', 3),
#      ('book', 3),
#      ('trip', 3),
#      ('place', 3),
#      ('save', 3),
#      ('close', 3),
#      ('refund', 3),
#      ('cancel', 3),
#      ('leave', 3),
#      ('right', 3),
#      ('measure', 3),
#      ('concern', 3),
#      ('pandemic', 3),
#      ('egg', 3),
#      ('information', 3),
#      ('analyst', 3),
#      ('break', 3),
#      ('team', 3),
#      ('tenant', 3),
#      ('post', 3),
#      ('thank', 3),
#      ('news', 3),
#      ('request', 3),
#      ('situation', 3),
#      ('speak', 3),
#      ('sale', 3),
#      ('shilla', 3),
#      ('relief', 3),
#      ('panic', 2),
#      ('grocery', 2),
#      ('read', 2),
#      ('shopper', 2),
#      ('coronacrisis', 2),
#      ('enjoy', 2),
#      ('life', 2),
#      ('finally', 2),
#      ('notice', 2),
#      ('service', 2),
#      ('catch', 2),
#      ('effect', 2),
#      ('restriction', 2),
#      ('event', 2),
#      ('buying', 2),
#      ('product', 2),
#      ('afford', 2),
#      ('sector', 2),
#      ('rise', 2),
#      ('follow', 2),
#      ('insight', 2),
#      ('start', 2),
#      ('world', 2),
#      ('publish', 2),
#      ('kid', 2),
#      ('contact', 2)]],
#    [3,
#     [('consumer', 32),
#      ('supermarket', 18),
#      ('business', 15),
#      ('worker', 12),
#      ('help', 11),
#      ('food', 11),
#      ('coronavirus', 10),
#      ('need', 10),
#      ('risk', 10),
#      ('supply', 9),
#      ('amp', 9),
#      ('support', 8),
#      ('shop', 8),
#      ('chain', 7),
#      ('people', 7),
#      ('staff', 7),
#      ('pay', 7),
#      ('demand', 6),
#      ('store', 6),
#      ('employee', 6),
#      ('change', 6),
#      ('offer', 6),
#      ('crisis', 6),
#      ('protect', 6),
#      ('feel', 5),
#      ('work', 5),
#      ('look', 5),
#      ('provide', 5),
#      ('mask', 5),
#      ('bank', 5),
#      ('learn', 5),
#      ('industry', 5),
#      ('protection', 5),
#      ('donate', 5),
#      ('stock', 4),
#      ('asda', 4),
#      ('virus', 4),
#      ('include', 4),
#      ('message', 4),
#      ('blog', 4),
#      ('news', 4),
#      ('time', 4),
#      ('grocery', 4),
#      ('country', 4),
#      ('report', 4),
#      ('check', 4),
#      ('join', 4),
#      ('come', 4),
#      ('choice', 4),
#      ('practice', 4),
#      ('scam', 4),
#      ('price', 3),
#      ('grocery_store', 3),
#      ('covid', 3),
#      ('health', 3),
#      ('information', 3),
#      ('glove', 3),
#      ('sign', 3),
#      ('family', 3),
#      ('follow', 3),
#      ('https', 3),
#      ('cut', 3),
#      ('force', 3),
#      ('nhs', 3),
#      ('face', 3),
#      ('happen', 3),
#      ('expert', 3),
#      ('contact', 3),
#      ('holiday', 3),
#      ('medium', 3),
#      ('wear', 3),
#      ('package', 3),
#      ('online', 3),
#      ('response', 3),
#      ('behaviour', 3),
#      ('remember', 3),
#      ('line', 3),
#      ('travel', 3),
#      ('stay', 3),
#      ('like', 3),
#      ('bring', 3),
#      ('purchase', 3),
#      ('send', 3),
#      ('home', 3),
#      ('economy', 2),
#      ('currently', 2),
#      ('delivery', 2),
#      ('week', 2),
#      ('read', 2),
#      ('money', 2),
#      ('spread', 2),
#      ('service', 2),
#      ('meal', 2),
#      ('today', 2),
#      ('order', 2),
#      ('lidlgb', 2),
#      ('roll', 2),
#      ('loan', 2),
#      ('situation', 2),
#      ('hour', 2)]],
#    [0,
#     [('price', 32),
#      ('coronavirus', 25),
#      ('oil', 22),
#      ('demand', 9),
#      ('fall', 9),
#      ('hand', 8),
#      ('food', 7),
#      ('economy', 7),
#      ('consumer', 6),
#      ('wash', 6),
#      ('supermarket', 5),
#      ('day', 5),
#      ('spread', 5),
#      ('people', 5),
#      ('covid', 5),
#      ('crisis', 5),
#      ('use', 5),
#      ('think', 5),
#      ('health', 5),
#      ('avoid', 5),
#      ('job', 5),
#      ('shortage', 5),
#      ('face', 4),
#      ('sanitizer', 4),
#      ('stay', 4),
#      ('company', 4),
#      ('gas', 4),
#      ('soap', 4),
#      ('win', 4),
#      ('tissue', 3),
#      ('world', 3),
#      ('market', 3),
#      ('know', 3),
#      ('ve', 3),
#      ('water', 3),
#      ('gold', 3),
#      ('lose', 3),
#      ('housing', 3),
#      ('cut', 3),
#      ('base', 3),
#      ('lockdown', 3),
#      ('need', 3),
#      ('hope', 3),
#      ('month', 3),
#      ('paper', 3),
#      ('term', 3),
#      ('cause', 3),
#      ('write', 3),
#      ('situation', 3),
#      ('grocery_store', 3),
#      ('help', 3),
#      ('change', 3),
#      ('post', 3),
#      ('state', 3),
#      ('income', 2),
#      ('let', 2),
#      ('create', 2),
#      ('support', 2),
#      ('toiletpaper', 2),
#      ('year', 2),
#      ('cover', 2),
#      ('secure', 2),
#      ('car', 2),
#      ('mouth', 2),
#      ('nose', 2),
#      ('order', 2),
#      ('social_distance', 2),
#      ('budget', 2),
#      ('plunge', 2),
#      ('force', 2),
#      ('alcohol', 2),
#      ('produce', 2),
#      ('approve', 2),
#      ('cent', 2),
#      ('seriously', 2),
#      ('maybe', 2),
#      ('head', 2),
#      ('expect', 2),
#      ('business', 2),
#      ('drug', 2),
#      ('week', 2),
#      ('war', 2),
#      ('damage', 2),
#      ('threat', 2),
#      ('supply', 2),
#      ('capital', 2),
#      ('election', 2),
#      ('economic', 2),
#      ('government', 2),
#      ('medium', 2),
#      ('come', 2),
#      ('control', 2),
#      ('trend', 2),
#      ('life', 2),
#      ('look', 2),
#      ('weigh', 2),
#      ('attempt', 2),
#      ('follow', 2),
#      ('holder', 2),
#      ('currently', 2)]]]},
#  {'Parameters': [0.05, 0.525],
#   'Loss': 0.49126213592233003,
#   'Doc Number': array([ 40,  35, 141, 125,  71]),
#   'Top Index': array([2, 3, 4, 0, 1]),
#   'Top Words': "\nCluster 2 : [('supermarket', 46), ('worker', 34), ('coronavirus', 28), ('covid', 24), ('grocery_store', 23), ('store', 22), ('work', 21), ('people', 20), ('shop', 18), ('home', 18)]\nCluster 3 : [('price', 48), ('food', 36), ('consumer', 35), ('coronavirus', 35), ('demand', 30), ('oil', 22), ('need', 13), ('covid', 13), ('supply', 12), ('change', 11)]\nCluster 4 : [('price', 29), ('coronavirus', 23), ('food', 15), ('people', 12), ('amp', 9), ('store', 8), ('panic', 8), ('toiletpaper', 8), ('thing', 7), ('stock', 7)]\nCluster 0 : [('consumer', 23), ('business', 10), ('coronavirus', 8), ('risk', 6), ('change', 6), ('covid', 5), ('crisis', 5), ('protection', 5), ('price', 4), ('join', 4)]\nCluster 1 : [('hand', 9), ('avoid', 7), ('people', 6), ('coronavirus', 6), ('toiletpaper', 6), ('wash', 6), ('sanitizer', 6), ('information', 6), ('supermarket', 5), ('covid', 5)]",
#   'All Words': [[2,
#     [('supermarket', 46),
#      ('worker', 34),
#      ('coronavirus', 28),
#      ('covid', 24),
#      ('grocery_store', 23),
#      ('store', 22),
#      ('work', 21),
#      ('people', 20),
#      ('shop', 18),
#      ('home', 18),
#      ('food', 18),
#      ('time', 17),
#      ('employee', 14),
#      ('staff', 13),
#      ('help', 13),
#      ('consumer', 9),
#      ('use', 9),
#      ('thank', 9),
#      ('chain', 9),
#      ('amp', 8),
#      ('line', 8),
#      ('week', 8),
#      ('hour', 8),
#      ('customer', 8),
#      ('protect', 8),
#      ('feel', 8),
#      ('buy', 7),
#      ('public', 7),
#      ('look', 7),
#      ('family', 7),
#      ('support', 7),
#      ('healthcare', 7),
#      ('stay', 7),
#      ('toiletpaper', 7),
#      ('grocery', 6),
#      ('face', 6),
#      ('mask', 6),
#      ('spread', 6),
#      ('need', 6),
#      ('today', 6),
#      ('place', 6),
#      ('virus', 6),
#      ('shelf', 6),
#      ('https', 6),
#      ('day', 6),
#      ('happen', 6),
#      ('right', 6),
#      ('delivery', 5),
#      ('know', 5),
#      ('pay', 5),
#      ('test', 5),
#      ('service', 5),
#      ('provide', 5),
#      ('run', 5),
#      ('risk', 5),
#      ('tell', 5),
#      ('remember', 5),
#      ('wait', 5),
#      ('close', 5),
#      ('think', 5),
#      ('thing', 5),
#      ('pharmacy', 5),
#      ('shopping', 5),
#      ('spend', 4),
#      ('stock', 4),
#      ('ære', 4),
#      ('care', 4),
#      ('purchase', 4),
#      ('site', 4),
#      ('serve', 4),
#      ('continue', 4),
#      ('glove', 4),
#      ('start', 4),
#      ('nursing', 4),
#      ('hospital', 4),
#      ('asda', 4),
#      ('limit', 4),
#      ('man', 4),
#      ('appreciate', 4),
#      ('outbreak', 4),
#      ('follow', 4),
#      ('infect', 4),
#      ('let', 4),
#      ('catch', 4),
#      ('way', 4),
#      ('avoid', 4),
#      ('floor', 4),
#      ('currently', 4),
#      ('sell', 3),
#      ('want', 3),
#      ('offer', 3),
#      ('health', 3),
#      ('love', 3),
#      ('team', 3),
#      ('nurse', 3),
#      ('doctor', 3),
#      ('frontline', 3),
#      ('nhs', 3),
#      ('fight', 3),
#      ('treatment', 3)]],
#    [3,
#     [('price', 48),
#      ('food', 36),
#      ('consumer', 35),
#      ('coronavirus', 35),
#      ('demand', 30),
#      ('oil', 22),
#      ('need', 13),
#      ('covid', 13),
#      ('supply', 12),
#      ('change', 11),
#      ('product', 11),
#      ('business', 10),
#      ('report', 10),
#      ('week', 10),
#      ('fall', 10),
#      ('people', 9),
#      ('service', 9),
#      ('face', 9),
#      ('help', 8),
#      ('stock', 8),
#      ('day', 8),
#      ('increase', 8),
#      ('economy', 8),
#      ('order', 7),
#      ('home', 7),
#      ('know', 7),
#      ('panic', 7),
#      ('shop', 7),
#      ('supermarket', 7),
#      ('watch', 7),
#      ('read', 7),
#      ('gas', 7),
#      ('household', 6),
#      ('industry', 6),
#      ('run', 6),
#      ('market', 6),
#      ('news', 6),
#      ('start', 6),
#      ('mask', 6),
#      ('meal', 6),
#      ('lockdown', 6),
#      ('case', 6),
#      ('health', 6),
#      ('impact', 6),
#      ('try', 6),
#      ('pay', 6),
#      ('purchase', 5),
#      ('sanitizer', 5),
#      ('come', 5),
#      ('income', 5),
#      ('support', 5),
#      ('rise', 5),
#      ('good', 5),
#      ('video', 5),
#      ('bank', 5),
#      ('want', 5),
#      ('stay', 4),
#      ('time', 4),
#      ('allow', 4),
#      ('item', 4),
#      ('buying', 4),
#      ('delivery', 4),
#      ('hand', 4),
#      ('profit', 4),
#      ('follow', 4),
#      ('donate', 4),
#      ('situation', 4),
#      ('box', 4),
#      ('seller', 4),
#      ('update', 4),
#      ('surge', 4),
#      ('world', 4),
#      ('lose', 4),
#      ('period', 4),
#      ('leave', 4),
#      ('job', 4),
#      ('company', 4),
#      ('crisis', 4),
#      ('receive', 4),
#      ('country', 4),
#      ('post', 4),
#      ('force', 3),
#      ('plan', 3),
#      ('look', 3),
#      ('panicbuye', 3),
#      ('amp', 3),
#      ('hospital', 3),
#      ('hike', 3),
#      ('create', 3),
#      ('sell', 3),
#      ('hope', 3),
#      ('cut', 3),
#      ('housing', 3),
#      ('tv', 3),
#      ('trump', 3),
#      ('medium', 3),
#      ('number', 3),
#      ('access', 3),
#      ('cover', 3),
#      ('confidence', 3)]],
#    [4,
#     [('price', 29),
#      ('coronavirus', 23),
#      ('food', 15),
#      ('people', 12),
#      ('amp', 9),
#      ('store', 8),
#      ('panic', 8),
#      ('toiletpaper', 8),
#      ('thing', 7),
#      ('stock', 7),
#      ('grocery', 7),
#      ('market', 6),
#      ('send', 6),
#      ('delivery', 5),
#      ('share', 5),
#      ('milk', 5),
#      ('state', 5),
#      ('crisis', 5),
#      ('pay', 5),
#      ('shortage', 5),
#      ('paper', 5),
#      ('emergency', 5),
#      ('travel', 5),
#      ('worker', 4),
#      ('money', 4),
#      ('buy', 4),
#      ('look', 4),
#      ('hike', 4),
#      ('end', 4),
#      ('outbreak', 4),
#      ('retailer', 4),
#      ('cause', 4),
#      ('control', 4),
#      ('sale', 4),
#      ('contact', 4),
#      ('break', 4),
#      ('reduce', 4),
#      ('love', 4),
#      ('work', 3),
#      ('report', 3),
#      ('world', 3),
#      ('fear', 3),
#      ('spread', 3),
#      ('gain', 3),
#      ('health', 3),
#      ('head', 3),
#      ('day', 3),
#      ('response', 3),
#      ('focus', 3),
#      ('thought', 3),
#      ('jack', 3),
#      ('price_gouge', 3),
#      ('pickup', 3),
#      ('run', 3),
#      ('pick', 3),
#      ('check', 3),
#      ('chicken', 3),
#      ('use', 3),
#      ('gold', 3),
#      ('trade', 3),
#      ('today', 3),
#      ('place', 3),
#      ('post', 3),
#      ('covid', 3),
#      ('hope', 3),
#      ('buyer', 3),
#      ('shilla', 3),
#      ('profiteer', 3),
#      ('help', 2),
#      ('home', 2),
#      ('mean', 2),
#      ('supermarket', 2),
#      ('speak', 2),
#      ('pandemic', 2),
#      ('prey', 2),
#      ('scammer', 2),
#      ('supply', 2),
#      ('time', 2),
#      ('demand', 2),
#      ('robot', 2),
#      ('tissue', 2),
#      ('law', 2),
#      ('write', 2),
#      ('way', 2),
#      ('choice', 2),
#      ('offer', 2),
#      ('news', 2),
#      ('station', 2),
#      ('mind', 2),
#      ('investment', 2),
#      ('promise', 2),
#      ('asset', 2),
#      ('pack', 2),
#      ('essay', 2),
#      ('job', 2),
#      ('stay', 2),
#      ('ensure', 2),
#      ('info', 2),
#      ('enjoy', 2),
#      ('book', 2)]],
#    [0,
#     [('consumer', 23),
#      ('business', 10),
#      ('coronavirus', 8),
#      ('risk', 6),
#      ('change', 6),
#      ('covid', 5),
#      ('crisis', 5),
#      ('protection', 5),
#      ('price', 4),
#      ('join', 4),
#      ('expert', 4),
#      ('payment', 4),
#      ('month', 4),
#      ('https', 4),
#      ('question', 4),
#      ('affect', 4),
#      ('review', 4),
#      ('impact', 4),
#      ('need', 3),
#      ('bank', 3),
#      ('loan', 3),
#      ('suspend', 3),
#      ('ve', 3),
#      ('product', 3),
#      ('company', 3),
#      ('announce', 3),
#      ('practice', 3),
#      ('industry', 3),
#      ('answer', 3),
#      ('mean', 3),
#      ('blog', 3),
#      ('share', 3),
#      ('amp', 3),
#      ('behavior', 3),
#      ('adapt', 3),
#      ('virus', 3),
#      ('behaviour', 3),
#      ('offer', 3),
#      ('week', 2),
#      ('help', 2),
#      ('follow', 2),
#      ('country', 2),
#      ('study', 2),
#      ('holiday', 2),
#      ('assistance', 2),
#      ('fee', 2),
#      ('discussion', 2),
#      ('tactic', 2),
#      ('step', 2),
#      ('amazon', 2),
#      ('message', 2),
#      ('read', 2),
#      ('lower', 2),
#      ('notice', 2),
#      ('home', 2),
#      ('case', 2),
#      ('wonder', 2),
#      ('learn', 2),
#      ('webinar', 2),
#      ('report', 2),
#      ('half', 2),
#      ('shut', 2),
#      ('time', 2),
#      ('include', 2),
#      ('brand', 2),
#      ('term', 2),
#      ('analysis', 2),
#      ('cut', 2),
#      ('resource', 2),
#      ('line', 2),
#      ('police', 2),
#      ('trend', 2),
#      ('credit', 2),
#      ('netflix', 2),
#      ('dominos', 2),
#      ('medium', 2),
#      ('fight', 2),
#      ('flight', 2),
#      ('refund', 2),
#      ('cbc', 2),
#      ('marketplace', 2),
#      ('cheat', 2),
#      ('sheet', 2),
#      ('vitamin', 2),
#      ('food', 2),
#      ('carbon', 2),
#      ('win', 2),
#      ('protocol', 2),
#      ('cpsuk', 2),
#      ('star', 2),
#      ('travel', 2),
#      ('thought', 1),
#      ('grocery_store', 1),
#      ('struggle', 1),
#      ('buy', 1),
#      ('quarenteen', 1),
#      ('ebook', 1),
#      ('cent', 1),
#      ('fantasy', 1),
#      ('novel', 1)]],
#    [1,
#     [('hand', 9),
#      ('avoid', 7),
#      ('people', 6),
#      ('coronavirus', 6),
#      ('toiletpaper', 6),
#      ('wash', 6),
#      ('sanitizer', 6),
#      ('information', 6),
#      ('supermarket', 5),
#      ('covid', 5),
#      ('use', 5),
#      ('cook', 4),
#      ('website', 4),
#      ('soap', 4),
#      ('check', 4),
#      ('distance', 4),
#      ('panic', 4),
#      ('today', 3),
#      ('coronaviru', 3),
#      ('base', 3),
#      ('let', 3),
#      ('relief', 3),
#      ('alcohol', 3),
#      ('ask', 3),
#      ('hand_sanitizer', 3),
#      ('video', 2),
#      ('consumer', 2),
#      ('life', 2),
#      ('thing', 2),
#      ('social_distance', 2),
#      ('quarantinelife', 2),
#      ('virus', 2),
#      ('deal', 2),
#      ('facebook', 2),
#      ('friend', 2),
#      ('tenant', 2),
#      ('follow', 2),
#      ('stop', 2),
#      ('far', 2),
#      ('water', 2),
#      ('request', 2),
#      ('mom', 2),
#      ('maybe', 2),
#      ('traffic', 2),
#      ('nose', 2),
#      ('mouth', 2),
#      ('catch', 2),
#      ('situation', 2),
#      ('cover', 2),
#      ('kill', 2),
#      ('germ', 2),
#      ('report', 2),
#      ('instagram', 2),
#      ('property', 2),
#      ('advice', 2),
#      ('believe', 2),
#      ('encourage', 2),
#      ('food', 2),
#      ('learn', 2),
#      ('search', 2),
#      ('walk', 2),
#      ('lady', 2),
#      ('buying', 2),
#      ('tell', 2),
#      ('touch', 2),
#      ('carrot', 2),
#      ('twitter', 2),
#      ('tissue', 2),
#      ('shop', 1),
#      ('know', 1),
#      ('delivery', 1),
#      ('shopping', 1),
#      ('bitch', 1),
#      ('society', 1),
#      ('wipe', 1),
#      ('seriously', 1),
#      ('perception', 1),
#      ('reality', 1),
#      ('grocerystore', 1),
#      ('nytime', 1),
#      ('qauhv', 1),
#      ('meet', 1),
#      ('bleach', 1),
#      ('bottle', 1),
#      ('religion', 1),
#      ('require', 1),
#      ('panicbuye', 1),
#      ('cyberbullye', 1),
#      ('hero', 1),
#      ('cooking', 1),
#      ('hit', 1),
#      ('thanksgive', 1),
#      ('level', 1),
#      ('high', 1),
#      ('skyrocket', 1),
#      ('consider', 1),
#      ('reminder', 1),
#      ('speak', 1),
#      ('nicely', 1),
#      ('grocery_store', 1)]]]},
#  {'Parameters': [0.05, 0.7625],
#   'Loss': 0.8844660194174756,
#   'Doc Number': array([195,  33, 152,  28,   4]),
#   'Top Index': array([0, 2, 1, 3, 4]),
#   'Top Words': "\nCluster 0 : [('supermarket', 51), ('coronavirus', 45), ('worker', 38), ('food', 34), ('people', 34), ('store', 31), ('covid', 28), ('grocery_store', 26), ('work', 23), ('home', 22)]\nCluster 2 : [('price', 63), ('consumer', 52), ('coronavirus', 42), ('food', 38), ('demand', 24), ('covid', 22), ('oil', 22), ('business', 16), ('change', 14), ('supply', 13)]\nCluster 1 : [('consumer', 11), ('coronavirus', 6), ('travel', 6), ('business', 5), ('crisis', 4), ('suspend', 4), ('review', 4), ('information', 4), ('price', 4), ('payment', 3)]\nCluster 3 : [('toiletpaper', 8), ('coronavirus', 7), ('avoid', 7), ('use', 6), ('sanitizer', 6), ('hand', 6), ('price', 5), ('wash', 5), ('supermarket', 4), ('soap', 4)]\nCluster 4 : [('consider', 1), ('coronaviru', 1), ('doctor', 1), ('wash', 1), ('distance', 1), ('today', 1), ('reminder', 1), ('hand', 1), ('speak', 1), ('nicely', 1)]",
#   'All Words': [[0,
#     [('supermarket', 51),
#      ('coronavirus', 45),
#      ('worker', 38),
#      ('food', 34),
#      ('people', 34),
#      ('store', 31),
#      ('covid', 28),
#      ('grocery_store', 26),
#      ('work', 23),
#      ('home', 22),
#      ('shop', 19),
#      ('help', 16),
#      ('know', 15),
#      ('time', 15),
#      ('employee', 14),
#      ('amp', 14),
#      ('thing', 14),
#      ('stock', 14),
#      ('day', 13),
#      ('look', 12),
#      ('staff', 12),
#      ('need', 11),
#      ('week', 11),
#      ('thank', 11),
#      ('grocery', 11),
#      ('price', 10),
#      ('customer', 10),
#      ('demand', 10),
#      ('run', 10),
#      ('toiletpaper', 10),
#      ('delivery', 10),
#      ('pay', 10),
#      ('buy', 9),
#      ('virus', 9),
#      ('family', 9),
#      ('feel', 9),
#      ('today', 9),
#      ('chain', 9),
#      ('use', 9),
#      ('panic', 8),
#      ('shelf', 8),
#      ('hour', 8),
#      ('line', 8),
#      ('provide', 8),
#      ('outbreak', 7),
#      ('close', 7),
#      ('service', 7),
#      ('mask', 7),
#      ('stay', 7),
#      ('tell', 7),
#      ('risk', 7),
#      ('purchase', 7),
#      ('start', 7),
#      ('support', 7),
#      ('milk', 7),
#      ('spread', 7),
#      ('pharmacy', 7),
#      ('test', 7),
#      ('want', 6),
#      ('let', 6),
#      ('place', 6),
#      ('ask', 6),
#      ('meal', 6),
#      ('case', 6),
#      ('healthcare', 6),
#      ('right', 6),
#      ('deliver', 6),
#      ('happen', 6),
#      ('money', 6),
#      ('public', 6),
#      ('spend', 5),
#      ('offer', 5),
#      ('consumer', 5),
#      ('hand', 5),
#      ('change', 5),
#      ('fight', 5),
#      ('ære', 5),
#      ('limit', 5),
#      ('https', 5),
#      ('health', 5),
#      ('community', 5),
#      ('catch', 5),
#      ('sale', 5),
#      ('way', 5),
# ...
#   'All Words': [[0,
#     [('price', 62),
#      ('coronavirus', 57),
#      ('food', 55),
#      ('consumer', 48),
#      ('demand', 32),
#      ('supermarket', 27),
#      ('people', 25),
#      ('covid', 25),
#      ('store', 24),
#      ('business', 23),
#      ('help', 22),
#      ('worker', 21),
#      ('oil', 21),
#      ('shop', 18),
#      ('grocery_store', 18),
#      ('time', 18),
#      ('change', 18),
#      ('work', 17),
#      ('crisis', 17),
#      ('home', 16),
#      ('supply', 15),
#      ('need', 14),
#      ('amp', 14),
#      ('report', 14),
#      ('week', 13),
#      ('pay', 13),
#      ('service', 12),
#      ('delivery', 12),
#      ('thank', 12),
#      ('employee', 12),
#      ('support', 12),
#      ('grocery', 12),
#      ('day', 12),
#      ('stay', 11),
#      ('fall', 10),
#      ('bank', 10),
#      ('run', 10),
#      ('https', 10),
#      ('panic', 9),
#      ('look', 9),
#      ('follow', 9),
#      ('offer', 9),
#      ('health', 9),
#      ('travel', 9),
#      ('industry', 9),
#      ('product', 9),
#      ('case', 9),
#      ('state', 8),
#      ('increase', 8),
#      ('risk', 8),
#      ('outbreak', 8),
#      ('news', 8),
#      ('order', 8),
#      ('gas', 8),
#      ('economy', 8),
#      ('spread', 8),
#      ('close', 8),
#      ('chain', 8),
#      ('face', 8),
#      ('start', 8),
#      ('deliver', 7),
#      ('shortage', 7),
#      ('information', 7),
#      ('continue', 7),
#      ('happen', 7),
#      ('hour', 7),
#      ('country', 7),
#      ('retailer', 7),
#      ('customer', 7),
#      ('shopping', 7),
#      ('line', 7),
#      ('stock', 6),
#      ('know', 6),
#      ('post', 6),
#      ('world', 6),
#      ('feel', 6),
#      ('price_gouge', 6),
#      ('hike', 6),
#      ('contact', 6),
#      ('fight', 6),
#      ('hope', 6),
#      ('online', 6),
#      ('practice', 6),
#      ('hit', 6),
#      ('response', 6),
#      ('come', 6),
#      ('rise', 6),
#      ('item', 6),
#      ('read', 6),
#      ('community', 6),
#      ('month', 6),
#      ('mask', 6),
#      ('household', 6),
#      ('check', 5),
#      ('market', 5),
#      ('plan', 5),
#      ('emergency', 5),
#      ('pharmacy', 5),
#      ('ensure', 5),
#      ('send', 5)]],
#    [3,
#     [('coronavirus', 33),
#      ('supermarket', 24),
#      ('people', 21),
#      ('toiletpaper', 20),
#      ('covid', 18),
#      ('food', 16),
#      ('use', 15),
#      ('thing', 14),
#      ('stock', 12),
#      ('avoid', 12),
#      ('hand', 12),
#      ('home', 11),
#      ('buy', 11),
#      ('price', 11),
#      ('work', 10),
#      ('grocery_store', 10),
#      ('store', 9),
#      ('today', 9),
#      ('know', 9),
#      ('sanitizer', 9),
#      ('panic', 9),
#      ('try', 8),
#      ('face', 7),
#      ('milk', 7),
#      ('distance', 7),
#      ('wash', 7),
#      ('place', 7),
#      ('catch', 6),
#      ('virus', 6),
#      ('time', 6),
#      ('chicken', 6),
#      ('day', 5),
#      ('market', 5),
#      ('cook', 5),
#      ('let', 5),
#      ('product', 5),
#      ('mask', 5),
#      ('family', 5),
#      ('kill', 5),
#      ('feel', 5),
#      ('love', 5),
#      ('consumer', 5),
#      ('public', 4),
#      ('share', 4),
#      ('alcohol', 4),
#      ('sale', 4),
#      ('coronacrisis', 4),
#      ('chain', 4),
#      ('run', 4),
#      ('spread', 4),
#      ('coronaviru', 4),
#      ('learn', 4),
#      ('crash', 4),
#      ('ask', 4),
#      ('relief', 4),
#      ('soap', 4),
#      ('limit', 4),
#      ('member', 4),
#      ('tell', 4),
#      ('friend', 4),
#      ('wipe', 4),
#      ('money', 4),
#      ('mean', 4),
#      ('purchase', 4),
#      ('request', 3),
#      ('water', 3),
#      ('situation', 3),
#      ('customer', 3),
#      ('trade', 3),
#      ('follow', 3),
#      ('report', 3),
#      ('shop', 3),
#      ('look', 3),
#      ('shelf', 3),
#      ('turn', 3),
#      ('package', 3),
#      ('gold', 3),
#      ('base', 3),
#      ('life', 3),
#      ('mind', 3),
#      ('company', 3),
#      ('stoppanicbuying', 3),
#      ('stophoarde', 3),
#      ('couple', 3),
#      ('maybe', 3),
#      ('government', 3),
#      ('quarantinelife', 3),
#      ('think', 3),
#      ('need', 3),
#      ('panicbuye', 3),
#      ('pack', 3),
#      ('sneeze', 3),
#      ('fear', 3),
#      ('house', 3),
#      ('send', 3),
#      ('video', 3),
#      ('way', 3),
#      ('head', 3),
#      ('spend', 3),
#      ('shut', 3)]],
#    [4,
#     [('worker', 16),
#      ('supermarket', 9),
#      ('staff', 9),
#      ('amp', 6),
#      ('shop', 6),
#      ('employee', 5),
#      ('coronavirus', 4),
#      ('covid', 4),
#      ('line', 4),
#      ('price', 3),
#      ('protect', 3),
#      ('team', 3),
#      ('nurse', 3),
#      ('doctor', 3),
#      ('glove', 3),
#      ('provide', 3),
#      ('duty', 3),
#      ('care', 3),
#      ('meal', 3),
#      ('nhs', 3),
#      ('want', 3),
#      ('driver', 3),
#      ('test', 3),
#      ('include', 3),
#      ('mask', 2),
#      ('sell', 2),
#      ('home', 2),
#      ('food', 2),
#      ('need', 2),
#      ('mean', 2),
#      ('look', 2),
#      ('help', 2),
#      ('asda', 2),
#      ('lidlgb', 2),
#      ('case', 2),
#      ('service', 2),
#      ('woman', 2),
#      ('hospital', 2),
#      ('floor', 2),
#      ('nursing', 2),
#      ('teacher', 2),
#      ('action', 2),
#      ('moment', 2),
#      ('tesco', 2),
#      ('public', 2),
#      ('testing', 2),
#      ('healthcare', 2),
#      ('health', 2),
#      ('deal', 2),
#      ('let', 2),
#      ('shaw', 2),
#      ('toilet_paper', 2),
#      ('assistant', 2),
#      ('locust', 2),
#      ('fuel', 2),
#      ('carrot', 2),
#      ('twitter', 2),
#      ('protocol', 2),
#      ('cpsuk', 2),
#      ('kit', 2),
#      ('feel', 1),
#      ('work', 1),
#      ('shelf', 1),
#      ('week', 1),
#      ('stock', 1),
#      ('start', 1),
#      ('site', 1),
#      ('confront', 1),
#      ('car', 1),
#      ('extremely', 1),
#      ('wear', 1),
#      ('world', 1),
#      ('drive', 1),
#      ('toiletpaper', 1),
#      ('emergency', 1),
#      ('provider', 1),
#      ('coronaviru', 1),
#      ('lysol', 1),
#      ('use', 1),
#      ('govts', 1),
#      ('cover', 1),
#      ('plain', 1),
#      ('repressive', 1),
#      ('distract', 1),
#      ('pressure', 1),
#      ('speak', 1),
#      ('bus', 1),
#      ('taxi', 1),
#      ('binman', 1),
#      ('pharmacist', 1),
#      ('assist', 1),
#      ('living', 1),
#      ('forget', 1),
#      ('staysafe', 1),
#      ('happen', 1),
#      ('goto', 1),
#      ('masse', 1),
#      ('idiot', 1),
#      ('pjs', 1),
#      ('bet', 1)]],
#    [2,
#     [('consumer', 16),
#      ('impact', 9),
#      ('price', 6),
#      ('coronavirus', 6),
#      ('video', 5),
#      ('week', 4),
#      ('covid', 3),
#      ('update', 3),
#      ('market', 3),
#      ('need', 3),
#      ('watch', 3),
#      ('amazon', 3),
#      ('analyst', 3),
#      ('response', 2),
#      ('amp', 2),
#      ('ve', 2),
#      ('use', 2),
#      ('cover', 2),
#      ('datum', 2),
#      ('read', 2),
#      ('concern', 2),
#      ('class', 2),
#      ('team', 2),
#      ('right', 2),
#      ('life', 2),
#      ('company', 2),
#      ('good', 2),
#      ('ecommerce', 2),
#      ('report', 2),
#      ('rj', 2),
#      ('plan', 2),
#      ('panic', 2),
#      ('buying', 2),
#      ('fix', 2),
#      ('income', 2),
#      ('essay', 2),
#      ('fight', 2),
#      ('flight', 2),
#      ('refund', 2),
#      ('cbc', 2),
#      ('marketplace', 2),
#      ('cheat', 2),
#      ('sheet', 2),
#      ('write', 2),
#      ('carbon', 2),
#      ('category', 2),
#      ('star', 2),
#      ('sector', 1),
#      ('change', 1),
#      ('reduce', 1),
#      ('behavior', 1),
#      ('join', 1),
#      ('research', 1),
#      ('industry', 1),
#      ('service', 1),
#      ('asset', 1),
#      ('post', 1),
#      ('decline', 1),
#      ('vaccine', 1),
#      ('event', 1),
#      ('article', 1),
#      ('choice', 1),
#      ('product', 1),
#      ('quarenteen', 1),
#      ('lower', 1),
#      ('ebook', 1),
#      ('cent', 1),
#      ('fantasy', 1),
#      ('novel', 1),
#      ('force', 1),
#      ('accept', 1),
#      ('cancellation', 1),
#      ('penalty', 1),
#      ('postponement', 1),
#      ('voucher', 1),
#      ('explain', 1),
#      ('internet', 1),
#      ('collaborate', 1),
#      ('publish', 1),
#      ('thought', 1),
#      ('reaction', 1),
#      ('derive', 1),
#      ('effect', 1),
#      ('urge', 1),
#      ('refrain', 1),
#      ('fear', 1),
#      ('mount', 1),
#      ('speak', 1),
#      ('council', 1),
#      ('stockpiling', 1),
#      ('experience', 1),
#      ('volatility', 1),
#      ('blog', 1),
#      ('fatveonxil', 1),
#      ('literacy', 1),
#      ('movement', 1),
#      ('happen', 1),
#      ('student', 1),
#      ('support', 1),
#      ('vulnerable', 1)]],
#    [1,
#     [('risk', 2),
#      ('vitamin', 2),
#      ('legit', 1),
#      ('know', 1),
#      ('reduce', 1),
#      ('infection', 1),
#      ('regulate', 1),
#      ('production', 1),
#      ('limit', 1),
#      ('virus', 1),
#      ('influenza', 1),
#      ('potentially', 1),
#      ('provide', 1),
#      ('protection', 1),
#      ('director', 1),
#      ('lflmoixnbi', 1),
#      ('sanitizer', 1),
#      ('valley', 1),
#      ('sanitzfree', 1),
#      ('bio', 1),
#      ('growout', 1),
#      ('hairoil', 1),
#      ('hairproblem', 1),
#      ('haircaretip', 1),
#      ('naturalhairoil', 1),
#      ('deal', 1),
#      ('offer', 1)]]]},
#  {'Parameters': [1.0, 1.0],
#   'Loss': 0.8796116504854369,
#   'Doc Number': array([ 66,   0,  97,   0, 249]),
#   'Top Index': array([4, 2, 0, 3, 1]),
#   'Top Words': "\nCluster 4 : [('coronavirus', 69), ('food', 61), ('consumer', 58), ('price', 39), ('people', 36), ('supermarket', 30), ('demand', 26), ('store', 26), ('covid', 25), ('business', 22)]\nCluster 2 : [('worker', 28), ('supermarket', 28), ('covid', 14), ('work', 13), ('home', 13), ('coronavirus', 12), ('grocery_store', 12), ('employee', 12), ('staff', 12), ('food', 10)]\nCluster 0 : [('price', 38), ('oil', 22), ('coronavirus', 19), ('covid', 11), ('toiletpaper', 10), ('fall', 9), ('people', 6), ('consumer', 5), ('gas', 5), ('economy', 5)]\nCluster 3 : []\nCluster 1 : []",
#   'All Words': [[4,
#     [('coronavirus', 69),
#      ('food', 61),
#      ('consumer', 58),
#      ('price', 39),
#      ('people', 36),
#      ('supermarket', 30),
#      ('demand', 26),
#      ('store', 26),
#      ('covid', 25),
#      ('business', 22),
#      ('change', 20),
#      ('panic', 19),
#      ('shop', 18),
#      ('help', 18),
#      ('need', 17),
#      ('report', 17),
#      ('thing', 16),
#      ('stock', 16),
#      ('home', 16),
#      ('grocery_store', 16),
#      ('time', 15),
#      ('work', 14),
#      ('amp', 14),
#      ('know', 14),
#      ('supply', 14),
#      ('grocery', 14),
#      ('buy', 13),
#      ('crisis', 13),
#      ('use', 13),
#      ('chain', 12),
#      ('product', 12),
#      ('toiletpaper', 12),
#      ('week', 12),
#      ('worker', 11),
#      ('pay', 11),
#      ('https', 10),
#      ('look', 10),
#      ('day', 10),
#      ('industry', 10),
#      ('health', 10),
#      ('delivery', 10),
#      ('today', 9),
#      ('stay', 9),
#      ('try', 9),
#      ('right', 9),
#      ('sanitizer', 9),
#      ('hand', 9),
#      ('avoid', 9),
#      ('share', 9),
#      ('impact', 9),
#      ('shopping', 9),
#      ('family', 9),
#      ('follow', 9),
#      ('bank', 9),
#      ('support', 9),
#      ('virus', 8),
#      ('market', 8),
#      ('face', 8),
#      ('run', 8),
#      ('case', 8),
#      ('purchase', 8),
#      ('spread', 8),
#      ('feel', 7),
#      ('company', 7),
#      ('buying', 7),
#      ('place', 7),
#      ('happen', 7),
#      ('let', 7),
#      ('retailer', 7),
#      ('shortage', 7),
#      ('video', 7),
#      ('milk', 7),
#      ('customer', 7),
#      ('outbreak', 7),
#      ('deliver', 7),
#      ('read', 7),
#      ('hike', 7),
#      ('mean', 6),
#      ('service', 6),
#      ('information', 6),
#      ('cause', 6),
#      ('increase', 6),
#      ('think', 6),
#      ('send', 6),
#      ('wash', 6),
#      ('continue', 6),
#      ('item', 6),
#      ('chicken', 6),
#      ('online', 6),
#      ('sale', 6),
#      ('ære', 6),
#      ('shelf', 6),
#      ('hope', 6),
#      ('learn', 6),
#      ('household', 6),
#      ('remember', 6),
#      ('offer', 6),
#      ('post', 6),
#      ('community', 6),
#      ('state', 6)]],
#    [2,
#     [('worker', 28),
#      ('supermarket', 28),
#      ('covid', 14),
#      ('work', 13),
#      ('home', 13),
#      ('coronavirus', 12),
#      ('grocery_store', 12),
#      ('employee', 12),
#      ('staff', 12),
#      ('food', 10),
#      ('thank', 9),
#      ('time', 9),
#      ('shop', 9),
#      ('mask', 8),
#      ('line', 8),
#      ('store', 7),
#      ('week', 7),
#      ('public', 7),
#      ('help', 7),
#      ('provide', 7),
#      ('service', 7),
#      ('fight', 7),
#      ('consumer', 6),
#      ('demand', 6),
#      ('hospital', 6),
#      ('hour', 6),
#      ('healthcare', 5),
#      ('start', 5),
#      ('team', 5),
#      ('price', 5),
#      ('nurse', 5),
#      ('face', 5),
#      ('feel', 5),
#      ('virus', 5),
#      ('site', 5),
#      ('meal', 5),
#      ('doctor', 5),
#      ('run', 5),
#      ('people', 5),
#      ('risk', 5),
#      ('income', 5),
#      ('delivery', 4),
#      ('close', 4),
#      ('watch', 4),
#      ('spread', 4),
#      ('amp', 4),
#      ('pay', 4),
#      ('outbreak', 4),
#      ('test', 4),
#      ('protect', 4),
#      ('glove', 4),
#      ('coronaviru', 4),
#      ('ask', 4),
#      ('travel', 4),
#      ('today', 4),
#      ('process', 4),
#      ('pharmacy', 3),
#      ('use', 3),
#      ('stay', 3),
#      ('need', 3),
#      ('customer', 3),
#      ('order', 3),
#      ('day', 3),
#      ('tesco', 3),
#      ('care', 3),
#      ('place', 3),
#      ('temporarily', 3),
#      ('nursing', 3),
#      ('infect', 3),
#      ('want', 3),
#      ('money', 3),
#      ('wait', 3),
#      ('include', 3),
#      ('testing', 3),
#      ('provider', 3),
#      ('ruin', 3),
#      ('serve', 3),
#      ('driver', 3),
#      ('sell', 3),
#      ('job', 3),
#      ('distance', 3),
#      ('nhs', 3),
#      ('attempt', 3),
#      ('floor', 3),
#      ('frontline', 3),
#      ('request', 3),
#      ('stophoarde', 3),
#      ('coronacrisis', 3),
#      ('relief', 3),
#      ('housing', 3),
#      ('cancel', 3),
#      ('come', 3),
#      ('measure', 3),
#      ('avoid', 3),
#      ('hand', 3),
#      ('refuse', 3),
#      ('product', 3),
#      ('refund', 3),
#      ('support', 2),
#      ('consider', 2)]],
#    [0,
#     [('price', 38),
#      ('oil', 22),
#      ('coronavirus', 19),
#      ('covid', 11),
#      ('toiletpaper', 10),
#      ('fall', 9),
#      ('people', 6),
#      ('consumer', 5),
#      ('gas', 5),
#      ('economy', 5),
#      ('amp', 5),
#      ('day', 4),
#      ('market', 4),
#      ('crisis', 4),
#      ('gold', 4),
#      ('cut', 4),
#      ('reduce', 4),
#      ('kill', 4),
#      ('world', 3),
#      ('use', 3),
#      ('order', 3),
#      ('paper', 3),
#      ('lose', 3),
#      ('mask', 3),
#      ('deal', 3),
#      ('look', 3),
#      ('meal', 3),
#      ('sign', 3),
#      ('stock', 3),
#      ('love', 3),
#      ('prisoner', 3),
#      ('https', 2),
#      ('demand', 2),
#      ('food', 2),
#      ('company', 2),
#      ('face', 2),
#      ('plunge', 2),
#      ('news', 2),
#      ('health', 2),
#      ('jack', 2),
#      ('support', 2),
#      ('cover', 2),
#      ('drug', 2),
#      ('heb', 2),
#      ('response', 2),
#      ('drop', 2),
#      ('threat', 2),
#      ('power', 2),
#      ('investment', 2),
#      ('stay', 2),
#      ('war', 2),
#      ('country', 2),
#      ('analysis', 2),
#      ('sell', 2),
#      ('surprise', 2),
#      ('earth', 2),
#      ('produce', 2),
#      ('start', 2),
#      ('approve', 2),
#      ('need', 2),
#      ('create', 2),
#      ('budget', 2),
#      ('follow', 2),
#      ('situation', 2),
#      ('increase', 2),
#      ('wipe', 2),
#      ('away', 2),
#      ('service', 2),
#      ('hand', 2),
#      ('month', 2),
#      ('tiktok', 2),
#      ('hand_sanitizer', 2),
#      ('shutdown', 2),
#      ('profiteer', 2),
#      ('recession', 2),
#      ('buy', 2),
#      ('come', 2),
#      ('prison', 2),
#      ('idea', 2),
#      ('offer', 2),
#      ('money', 2),
#      ('barrel', 2),
#      ('dominos', 2),
#      ('shut', 2),
#      ('crack', 2),
#      ('want', 2),
#      ('police', 2),
#      ('realtor', 2),
#      ('toilet_paper', 2),
#      ('price_gouge', 2),
#      ('morning', 2),
#      ('ics', 2),
#      ('instagram', 2),
#      ('stop', 2),
#      ('carrot', 2),
#      ('check', 2),
#      ('carbon', 2),
#      ('twitter', 2),
#      ('supermarket', 2),
#      ('competition', 2)]],
#    [3, []],
#    [1, []]]}]

# %%
ResultsDF
# Out:
#           Parameters      Loss              Doc Number        Top Index  \
# 0       [0.05, 0.05]  0.112621    [81, 93, 66, 77, 95]  [4, 1, 0, 3, 2]
# 1     [0.05, 0.2875]  0.151456   [65, 113, 83, 75, 76]  [1, 2, 4, 3, 0]
# 2      [0.05, 0.525]  0.491262  [40, 35, 141, 125, 71]  [2, 3, 4, 0, 1]
# 3     [0.05, 0.7625]  0.884466   [195, 33, 152, 28, 4]  [0, 2, 1, 3, 4]
# 4        [0.05, 1.0]  1.166019     [212, 193, 0, 0, 7]  [0, 1, 4, 3, 2]
# 5     [0.2875, 0.05]  0.134951   [83, 63, 101, 74, 91]  [2, 4, 0, 3, 1]
# 6   [0.2875, 0.2875]  0.345631   [72, 60, 143, 93, 44]  [2, 3, 0, 1, 4]
# 7    [0.2875, 0.525]  0.578641  [179, 38, 77, 105, 13]  [0, 3, 2, 1, 4]
# 8   [0.2875, 0.7625]  0.738835   [73, 152, 18, 4, 165]  [4, 1, 0, 2, 3]
# 9      [0.2875, 1.0]  1.068932    [276, 16, 109, 6, 5]  [0, 2, 1, 3, 4]
# 10     [0.525, 0.05]  0.134951    [92, 98, 71, 66, 85]  [1, 0, 4, 2, 3]
# 11   [0.525, 0.2875]  0.267961   [68, 59, 90, 65, 130]  [4, 2, 0, 3, 1]
# 12    [0.525, 0.525]  0.600000   [79, 54, 46, 27, 206]  [4, 0, 1, 2, 3]
# 13   [0.525, 0.7625]  0.667961   [220, 35, 68, 32, 57]  [0, 2, 4, 1, 3]
# 14      [0.525, 1.0]  1.025243    [177, 199, 29, 4, 3]  [1, 0, 2, 3, 4]
# 15    [0.7625, 0.05]  0.253398  [65, 64, 110, 66, 107]  [2, 4, 3, 0, 1]
# 16  [0.7625, 0.2875]  0.384466  [105, 43, 72, 139, 53]  [3, 0, 2, 4, 1]
# 17   [0.7625, 0.525]  0.394175  [117, 60, 72, 129, 34]  [3, 0, 2, 1, 4]
# 18  [0.7625, 0.7625]  0.612621   [100, 54, 5, 62, 191]  [4, 0, 3, 1, 2]
# 19     [0.7625, 1.0]  0.680583   [0, 80, 177, 27, 128]  [2, 4, 1, 3, 0]
# 20       [1.0, 0.05]  0.134951    [90, 98, 87, 63, 74]  [1, 0, 2, 4, 3]
# 21     [1.0, 0.2875]  0.352427   [81, 67, 71, 38, 155]  [4, 0, 2, 1, 3]
# 22      [1.0, 0.525]  0.583495    [91, 194, 9, 44, 74]  [1, 0, 4, 3, 2]
# 23     [1.0, 0.7625]  0.942718   [236, 2, 22, 123, 29]  [0, 3, 4, 2, 1]
# 24        [1.0, 1.0]  0.879612     [66, 0, 97, 0, 249]  [4, 2, 0, 3, 1]
#
#                                             Top Words  \
# 0   \nCluster 4 : [('consumer', 31), ('coronavirus...
# 1   \nCluster 1 : [('supermarket', 30), ('coronavi...
# 2   \nCluster 2 : [('supermarket', 46), ('worker',...
# 3   \nCluster 0 : [('supermarket', 51), ('coronavi...
# 4   \nCluster 0 : [('price', 79), ('consumer', 64)...
# 5   \nCluster 2 : [('coronavirus', 25), ('worker',...
# 6   \nCluster 2 : [('supermarket', 43), ('coronavi...
# 7   \nCluster 0 : [('food', 56), ('coronavirus', 3...
# 8   \nCluster 4 : [('coronavirus', 39), ('people',...
# 9   \nCluster 0 : [('coronavirus', 65), ('food', 5...
# 10  \nCluster 1 : [('worker', 31), ('food', 26), (...
# 11  \nCluster 4 : [('price', 47), ('food', 40), ('...
# 12  \nCluster 4 : [('coronavirus', 47), ('food', 4...
# 13  \nCluster 0 : [('food', 61), ('supermarket', 5...
# 14  \nCluster 1 : [('coronavirus', 55), ('price', ...
# 15  \nCluster 2 : [('food', 29), ('people', 24), (...
# 16  \nCluster 3 : [('food', 35), ('people', 27), (...
# 17  \nCluster 3 : [('food', 38), ('worker', 35), (...
# 18  \nCluster 4 : [('coronavirus', 44), ('supermar...
# 19  \nCluster 2 : [('food', 59), ('price', 47), ('...
# 20  \nCluster 1 : [('food', 34), ('consumer', 24),...
# 21  \nCluster 4 : [('supermarket', 41), ('worker',...
# 22  \nCluster 1 : [('food', 48), ('supermarket', 4...
# 23  \nCluster 0 : [('price', 62), ('coronavirus', ...
# 24  \nCluster 4 : [('coronavirus', 69), ('food', 6...
#
#                                             All Words  \
# 0   [[4, [('consumer', 31), ('coronavirus', 30), (...
# 1   [[1, [('supermarket', 30), ('coronavirus', 27)...
# 2   [[2, [('supermarket', 46), ('worker', 34), ('c...
# 3   [[0, [('supermarket', 51), ('coronavirus', 45)...
# 4   [[0, [('price', 79), ('consumer', 64), ('coron...
# 5   [[2, [('coronavirus', 25), ('worker', 24), ('c...
# 6   [[2, [('supermarket', 43), ('coronavirus', 30)...
# 7   [[0, [('food', 56), ('coronavirus', 38), ('sup...
# 8   [[4, [('coronavirus', 39), ('people', 39), ('s...
# 9   [[0, [('coronavirus', 65), ('food', 59), ('sup...
# 10  [[1, [('worker', 31), ('food', 26), ('price', ...
# 11  [[4, [('price', 47), ('food', 40), ('coronavir...
# 12  [[4, [('coronavirus', 47), ('food', 45), ('sup...
# 13  [[0, [('food', 61), ('supermarket', 52), ('cor...
# 14  [[1, [('coronavirus', 55), ('price', 52), ('pe...
# 15  [[2, [('food', 29), ('people', 24), ('coronavi...
# 16  [[3, [('food', 35), ('people', 27), ('coronavi...
# 17  [[3, [('food', 38), ('worker', 35), ('supermar...
# 18  [[4, [('coronavirus', 44), ('supermarket', 38)...
# 19  [[2, [('food', 59), ('price', 47), ('coronavir...
# 20  [[1, [('food', 34), ('consumer', 24), ('corona...
# 21  [[4, [('supermarket', 41), ('worker', 38), ('f...
# 22  [[1, [('food', 48), ('supermarket', 45), ('cor...
# 23  [[0, [('price', 62), ('coronavirus', 57), ('fo...
# 24  [[4, [('coronavirus', 69), ('food', 61), ('con...
#
#                                             Cluster 0  \
# 0   ('price', 21), ('coronavirus', 21), ('covid', ...
# 1   ('price', 32), ('coronavirus', 25), ('oil', 22...
# 2   ('consumer', 23), ('business', 10), ('coronavi...
# 3   ('supermarket', 51), ('coronavirus', 45), ('wo...
# 4   ('price', 79), ('consumer', 64), ('coronavirus...
# 5   ('price', 29), ('consumer', 26), ('coronavirus...
# 6   ('coronavirus', 28), ('toiletpaper', 20), ('pe...
# 7   ('food', 56), ('coronavirus', 38), ('supermark...
# 8   ('worker', 30), ('supermarket', 22), ('employe...
# 9   ('coronavirus', 65), ('food', 59), ('supermark...
# 10  ('price', 33), ('coronavirus', 26), ('food', 2...
# 11  ('worker', 20), ('supermarket', 19), ('coronav...
# 12  ('coronavirus', 27), ('consumer', 26), ('price...
# 13  ('food', 61), ('supermarket', 52), ('coronavir...
# 14  ('food', 42), ('consumer', 42), ('coronavirus'...
# 15  ('coronavirus', 17), ('toiletpaper', 13), ('su...
# 16  ('coronavirus', 30), ('food', 25), ('price', 2...
# 17  ('coronavirus', 29), ('covid', 24), ('price', ...
# 18  ('price', 47), ('coronavirus', 30), ('food', 2...
# 19
# 20  ('coronavirus', 23), ('store', 14), ('supermar...
# 21  ('coronavirus', 23), ('covid', 16), ('supermar...
# 22  ('price', 43), ('consumer', 33), ('coronavirus...
# 23  ('price', 62), ('coronavirus', 57), ('food', 5...
# 24  ('price', 38), ('oil', 22), ('coronavirus', 19...
#
#                                             Cluster 1  \
# 0   ('supermarket', 27), ('worker', 27), ('grocery...
# 1   ('supermarket', 30), ('coronavirus', 27), ('wo...
# 2   ('hand', 9), ('avoid', 7), ('people', 6), ('co...
# 3   ('consumer', 11), ('coronavirus', 6), ('travel...
# 4   ('supermarket', 54), ('coronavirus', 38), ('wo...
# 5   ('coronavirus', 16), ('people', 11), ('toiletp...
# 6   ('price', 46), ('coronavirus', 22), ('oil', 22...
# 7   ('worker', 11), ('supermarket', 10), ('shop', ...
# 8   ('price', 71), ('coronavirus', 45), ('consumer...
# 9   ('toiletpaper', 9), ('coronavirus', 4), ('supe...
# 10  ('worker', 31), ('food', 26), ('price', 23), (...
# 11  ('supermarket', 16), ('consumer', 10), ('hand'...
# 12  ('price', 35), ('oil', 16), ('coronavirus', 10...
# 13  ('consumer', 31), ('business', 8), ('change', ...
# 14  ('coronavirus', 55), ('price', 52), ('people',...
# 15  ('coronavirus', 25), ('price', 23), ('consumer...
# 16  ('worker', 16), ('supermarket', 14), ('staff',...
# 17  ('consumer', 24), ('coronavirus', 20), ('price...
# 18  ('consumer', 30), ('coronavirus', 12), ('covid...
# 19  ('worker', 30), ('supermarket', 24), ('coronav...
# 20  ('food', 34), ('consumer', 24), ('coronavirus'...
# 21  ('price', 44), ('coronavirus', 25), ('oil', 19...
# 22  ('food', 48), ('supermarket', 45), ('coronavir...
# 23  ('risk', 2), ('vitamin', 2), ('legit', 1), ('k...
# 24
#
#                                             Cluster 2  \
# 0   ('price', 14), ('food', 14), ('coronavirus', 1...
# 1   ('food', 31), ('coronavirus', 30), ('price', 2...
# 2   ('supermarket', 46), ('worker', 34), ('coronav...
# 3   ('price', 63), ('consumer', 52), ('coronavirus...
# 4
# 5   ('coronavirus', 25), ('worker', 24), ('consume...
# 6   ('supermarket', 43), ('coronavirus', 30), ('fo...
# 7   ('coronavirus', 19), ('toiletpaper', 15), ('su...
# 8   ('toiletpaper', 10), ('coronavirus', 6), ('pap...
# 9   ('consumer', 46), ('price', 44), ('coronavirus...
# 10  ('coronavirus', 22), ('price', 17), ('consumer...
# 11  ('coronavirus', 24), ('covid', 22), ('food', 1...
# 12  ('coronavirus', 16), ('toiletpaper', 11), ('us...
# 13  ('price', 48), ('coronavirus', 23), ('oil', 22...
# 14  ('consumer', 20), ('coronavirus', 6), ('change...
# 15  ('food', 29), ('people', 24), ('coronavirus', ...
# 16  ('consumer', 44), ('coronavirus', 22), ('price...
# 17  ('price', 40), ('coronavirus', 23), ('oil', 21...
# 18  ('supermarket', 3), ('love', 2), ('line', 2), ...
# 19  ('food', 59), ('price', 47), ('coronavirus', 4...
# 20  ('consumer', 28), ('coronavirus', 22), ('food'...
# 21  ('food', 26), ('consumer', 23), ('demand', 17)...
# 22  ('shop', 3), ('line', 3), ('deal', 3), ('shopp...
# 23  ('consumer', 16), ('impact', 9), ('price', 6),...
# 24  ('worker', 28), ('supermarket', 28), ('covid',...
#
#                                             Cluster 3  \
# 0   ('coronavirus', 23), ('consumer', 22), ('price...
# 1   ('consumer', 32), ('supermarket', 18), ('busin...
# 2   ('price', 48), ('food', 36), ('consumer', 35),...
# 3   ('toiletpaper', 8), ('coronavirus', 7), ('avoi...
# 4
# 5   ('supermarket', 26), ('covid', 19), ('grocery_...
# 6   ('food', 29), ('price', 23), ('consumer', 19),...
# 7   ('consumer', 46), ('price', 41), ('coronavirus...
# 8   ('crisis', 2), ('carrot', 2), ('deal', 2), ('l...
# 9   ('relief', 3), ('request', 2), ('check', 2), (...
# 10  ('consumer', 25), ('coronavirus', 15), ('peopl...
# 11  ('consumer', 28), ('coronavirus', 16), ('price...
# 12  ('supermarket', 12), ('staff', 10), ('worker',...
# 13  ('hand', 9), ('supermarket', 6), ('wash', 6), ...
# 14  ('line', 2), ('locust', 2), ('carrot', 2), ('k...
# 15  ('consumer', 24), ('worker', 16), ('supermarke...
# 16  ('food', 35), ('people', 27), ('coronavirus', ...
# 17  ('food', 38), ('worker', 35), ('supermarket', ...
# 18  ('panic', 15), ('food', 15), ('coronavirus', 1...
# 19  ('price', 18), ('oil', 12), ('coronavirus', 5)...
# 20  ('price', 33), ('coronavirus', 23), ('oil', 22...
# 21  ('consumer', 18), ('business', 8), ('price', 7...
# 22  ('coronavirus', 12), ('sanitizer', 9), ('toile...
# 23  ('coronavirus', 33), ('supermarket', 24), ('pe...
# 24
#
#                                             Cluster 4  \
# 0   ('consumer', 31), ('coronavirus', 30), ('food'...
# 1   ('price', 20), ('consumer', 14), ('covid', 13)...
# 2   ('price', 29), ('coronavirus', 23), ('food', 1...
# 3   ('consider', 1), ('coronaviru', 1), ('doctor',...
# 4   ('turn', 2), ('sanitizer', 2), ('terf', 2), ('...
# 5   ('coronavirus', 27), ('price', 27), ('food', 2...
# 6   ('consumer', 22), ('coronavirus', 10), ('check...
# 7   ('price', 6), ('coronavirus', 6), ('toiletpape...
# 8   ('coronavirus', 39), ('people', 39), ('superma...
# 9   ('line', 2), ('protocol', 2), ('cpsuk', 2), ('...
# 10  ('supermarket', 30), ('coronavirus', 18), ('pe...
# 11  ('price', 47), ('food', 40), ('coronavirus', 3...
# 12  ('coronavirus', 47), ('food', 45), ('supermark...
# 13  ('coronavirus', 25), ('toiletpaper', 15), ('pr...
# 14  ('thumbsup', 1), ('toiletpaper', 1), ('lack', ...
# 15  ('coronavirus', 33), ('price', 33), ('consumer...
# 16  ('price', 17), ('coronavirus', 13), ('people',...
# 17  ('supermarket', 14), ('avoid', 8), ('hand', 8)...
# 18  ('coronavirus', 44), ('supermarket', 38), ('wo...
# 19  ('coronavirus', 35), ('supermarket', 25), ('co...
# 20  ('worker', 27), ('supermarket', 24), ('work', ...
# 21  ('supermarket', 41), ('worker', 38), ('food', ...
# 22  ('consumer', 29), ('coronavirus', 19), ('price...
# 23  ('worker', 16), ('supermarket', 9), ('staff', ...
# 24  ('coronavirus', 69), ('food', 61), ('consumer'...
#
#                                         All Cluster 0  \
# 0   [[(price, 21), (coronavirus, 21), (covid, 13),...
# 1   [[(price, 32), (coronavirus, 25), (oil, 22), (...
# 2   [[(consumer, 23), (business, 10), (coronavirus...
# 3   [[(supermarket, 51), (coronavirus, 45), (worke...
# 4   [[(price, 79), (consumer, 64), (coronavirus, 6...
# 5   [[(price, 29), (consumer, 26), (coronavirus, 2...
# 6   [[(coronavirus, 28), (toiletpaper, 20), (peopl...
# 7   [[(food, 56), (coronavirus, 38), (supermarket,...
# 8   [[(worker, 30), (supermarket, 22), (employee, ...
# 9   [[(coronavirus, 65), (food, 59), (supermarket,...
# 10  [[(price, 33), (coronavirus, 26), (food, 25), ...
# 11  [[(worker, 20), (supermarket, 19), (coronaviru...
# 12  [[(coronavirus, 27), (consumer, 26), (price, 2...
# 13  [[(food, 61), (supermarket, 52), (coronavirus,...
# 14  [[(food, 42), (consumer, 42), (coronavirus, 39...
# 15  [[(coronavirus, 17), (toiletpaper, 13), (super...
# 16  [[(coronavirus, 30), (food, 25), (price, 22), ...
# 17  [[(coronavirus, 29), (covid, 24), (price, 20),...
# 18  [[(price, 47), (coronavirus, 30), (food, 23), ...
# 19                                               [[]]
# 20  [[(coronavirus, 23), (store, 14), (supermarket...
# 21  [[(coronavirus, 23), (covid, 16), (supermarket...
# 22  [[(price, 43), (consumer, 33), (coronavirus, 2...
# 23  [[(price, 62), (coronavirus, 57), (food, 55), ...
# 24  [[(price, 38), (oil, 22), (coronavirus, 19), (...
#
#                                         All Cluster 1  \
# 0   [[(supermarket, 27), (worker, 27), (grocery_st...
# 1   [[(supermarket, 30), (coronavirus, 27), (worke...
# 2   [[(hand, 9), (avoid, 7), (people, 6), (coronav...
# 3   [[(consumer, 11), (coronavirus, 6), (travel, 6...
# 4   [[(supermarket, 54), (coronavirus, 38), (worke...
# 5   [[(coronavirus, 16), (people, 11), (toiletpape...
# 6   [[(price, 46), (coronavirus, 22), (oil, 22), (...
# 7   [[(worker, 11), (supermarket, 10), (shop, 8), ...
# 8   [[(price, 71), (coronavirus, 45), (consumer, 4...
# 9   [[(toiletpaper, 9), (coronavirus, 4), (superma...
# 10  [[(worker, 31), (food, 26), (price, 23), (coro...
# 11  [[(supermarket, 16), (consumer, 10), (hand, 10...
# 12  [[(price, 35), (oil, 16), (coronavirus, 10), (...
# 13  [[(consumer, 31), (business, 8), (change, 8), ...
# 14  [[(coronavirus, 55), (price, 52), (people, 40)...
# 15  [[(coronavirus, 25), (price, 23), (consumer, 1...
# 16  [[(worker, 16), (supermarket, 14), (staff, 13)...
# 17  [[(consumer, 24), (coronavirus, 20), (price, 1...
# 18  [[(consumer, 30), (coronavirus, 12), (covid, 1...
# 19  [[(worker, 30), (supermarket, 24), (coronaviru...
# 20  [[(food, 34), (consumer, 24), (coronavirus, 23...
# 21  [[(price, 44), (coronavirus, 25), (oil, 19), (...
# 22  [[(food, 48), (supermarket, 45), (coronavirus,...
# 23  [[(risk, 2), (vitamin, 2), (legit, 1), (know, ...
# 24                                               [[]]
#
#                                         All Cluster 2  \
# 0   [[(price, 14), (food, 14), (coronavirus, 13), ...
# 1   [[(food, 31), (coronavirus, 30), (price, 27), ...
# 2   [[(supermarket, 46), (worker, 34), (coronaviru...
# 3   [[(price, 63), (consumer, 52), (coronavirus, 4...
# 4                                                [[]]
# 5   [[(coronavirus, 25), (worker, 24), (consumer, ...
# 6   [[(supermarket, 43), (coronavirus, 30), (food,...
# 7   [[(coronavirus, 19), (toiletpaper, 15), (super...
# 8   [[(toiletpaper, 10), (coronavirus, 6), (paper,...
# 9   [[(consumer, 46), (price, 44), (coronavirus, 3...
# 10  [[(coronavirus, 22), (price, 17), (consumer, 1...
# 11  [[(coronavirus, 24), (covid, 22), (food, 16), ...
# 12  [[(coronavirus, 16), (toiletpaper, 11), (use, ...
# 13  [[(price, 48), (coronavirus, 23), (oil, 22), (...
# 14  [[(consumer, 20), (coronavirus, 6), (change, 5...
# 15  [[(food, 29), (people, 24), (coronavirus, 20),...
# 16  [[(consumer, 44), (coronavirus, 22), (price, 2...
# 17  [[(price, 40), (coronavirus, 23), (oil, 21), (...
# 18  [[(supermarket, 3), (love, 2), (line, 2), (dis...
# 19  [[(food, 59), (price, 47), (coronavirus, 44), ...
# 20  [[(consumer, 28), (coronavirus, 22), (food, 19...
# 21  [[(food, 26), (consumer, 23), (demand, 17), (c...
# 22  [[(shop, 3), (line, 3), (deal, 3), (shopping, ...
# 23  [[(consumer, 16), (impact, 9), (price, 6), (co...
# 24  [[(worker, 28), (supermarket, 28), (covid, 14)...
#
#                                         All Cluster 3  \
# 0   [[(coronavirus, 23), (consumer, 22), (price, 2...
# 1   [[(consumer, 32), (supermarket, 18), (business...
# 2   [[(price, 48), (food, 36), (consumer, 35), (co...
# 3   [[(toiletpaper, 8), (coronavirus, 7), (avoid, ...
# 4                                                [[]]
# 5   [[(supermarket, 26), (covid, 19), (grocery_sto...
# 6   [[(food, 29), (price, 23), (consumer, 19), (de...
# 7   [[(consumer, 46), (price, 41), (coronavirus, 3...
# 8   [[(crisis, 2), (carrot, 2), (deal, 2), (let, 1...
# 9   [[(relief, 3), (request, 2), (check, 2), (hand...
# 10  [[(consumer, 25), (coronavirus, 15), (people, ...
# 11  [[(consumer, 28), (coronavirus, 16), (price, 1...
# 12  [[(supermarket, 12), (staff, 10), (worker, 9),...
# 13  [[(hand, 9), (supermarket, 6), (wash, 6), (san...
# 14  [[(line, 2), (locust, 2), (carrot, 2), (kit, 2...
# 15  [[(consumer, 24), (worker, 16), (supermarket, ...
# 16  [[(food, 35), (people, 27), (coronavirus, 27),...
# 17  [[(food, 38), (worker, 35), (supermarket, 29),...
# 18  [[(panic, 15), (food, 15), (coronavirus, 14), ...
# 19  [[(price, 18), (oil, 12), (coronavirus, 5), (e...
# 20  [[(price, 33), (coronavirus, 23), (oil, 22), (...
# 21  [[(consumer, 18), (business, 8), (price, 7), (...
# 22  [[(coronavirus, 12), (sanitizer, 9), (toiletpa...
# 23  [[(coronavirus, 33), (supermarket, 24), (peopl...
# 24                                               [[]]
#
#                                         All Cluster 4
# 0   [[(consumer, 31), (coronavirus, 30), (food, 28...
# 1   [[(price, 20), (consumer, 14), (covid, 13), (w...
# 2   [[(price, 29), (coronavirus, 23), (food, 15), ...
# 3   [[(consider, 1), (coronaviru, 1), (doctor, 1),...
# 4   [[(turn, 2), (sanitizer, 2), (terf, 2), (carro...
# 5   [[(coronavirus, 27), (price, 27), (food, 21), ...
# 6   [[(consumer, 22), (coronavirus, 10), (check, 7...
# 7   [[(price, 6), (coronavirus, 6), (toiletpaper, ...
# 8   [[(coronavirus, 39), (people, 39), (supermarke...
# 9   [[(line, 2), (protocol, 2), (cpsuk, 2), (kit, ...
# 10  [[(supermarket, 30), (coronavirus, 18), (peopl...
# 11  [[(price, 47), (food, 40), (coronavirus, 38), ...
# 12  [[(coronavirus, 47), (food, 45), (supermarket,...
# 13  [[(coronavirus, 25), (toiletpaper, 15), (price...
# 14  [[(thumbsup, 1), (toiletpaper, 1), (lack, 1), ...
# 15  [[(coronavirus, 33), (price, 33), (consumer, 2...
# 16  [[(price, 17), (coronavirus, 13), (people, 10)...
# 17  [[(supermarket, 14), (avoid, 8), (hand, 8), (u...
# 18  [[(coronavirus, 44), (supermarket, 38), (worke...
# 19  [[(coronavirus, 35), (supermarket, 25), (consu...
# 20  [[(worker, 27), (supermarket, 24), (work, 17),...
# 21  [[(supermarket, 41), (worker, 38), (food, 33),...
# 22  [[(consumer, 29), (coronavirus, 19), (price, 1...
# 23  [[(worker, 16), (supermarket, 9), (staff, 9), ...
# 24  [[(coronavirus, 69), (food, 61), (consumer, 58...
