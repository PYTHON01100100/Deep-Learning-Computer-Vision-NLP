# %%
T = '''World War II or the Second World War, often abbreviated as WWII or WW2, was a global conflict that lasted from 1939 to 1945. The vast majority of the world's countries, including all of the great powers, fought as part of two opposing military alliances: the Allies and the Axis. Many participants threw their economic, industrial, and scientific capabilities behind this total war, blurring the distinction between civilian and military resources. Aircraft played a major role, enabling the strategic bombing of population centres and the delivery of the only two nuclear weapons ever used in war. World War II was by far the deadliest conflict in history, resulting in an estimated 70 to 85 million fatalities, mostly among civilians. Tens of millions died due to genocides (including the Holocaust), starvation, massacres, and disease. In the wake of Axis defeat, Germany, Austria and Japan were occupied, and war crimes tribunals were conducted against German and Japanese leaders.
The causes of World War II are debated, but contributing factors included the Second Italo-Ethiopian War, Spanish Civil War, Second Sino-Japanese War, Soviet–Japanese border conflicts, the rise of fascism in Europe, and European tensions in the aftermath of World War I. World War II is generally considered to have begun on 1 September 1939, when Nazi Germany, under Adolf Hitler, invaded Poland. The United Kingdom and France subsequently declared war on Germany on 3 September. Under the Molotov–Ribbentrop Pact of August 1939, Germany and the Soviet Union had partitioned Poland and marked out their "spheres of influence" across Finland, Estonia, Latvia, Lithuania and Romania. From late 1939 to early 1941, in a series of campaigns and treaties, Germany conquered or controlled much of continental Europe, in a military alliance with Italy, Japan and other countries called the Axis. Following the onset of campaigns in North Africa and East Africa, and the fall of France in mid-1940, the war continued primarily between the Euro
'''

T = T.lower()
T
# Out:
# 'world war ii or the second world war, often abbreviated as wwii or ww2, was a global conflict that lasted from 1939 to 1945. the vast majority of the world\'s countries, including all of the great powers, fought as part of two opposing military alliances: the allies and the axis. many participants threw their economic, industrial, and scientific capabilities behind this total war, blurring the distinction between civilian and military resources. aircraft played a major role, enabling the strategic bombing of population centres and the delivery of the only two nuclear weapons ever used in war. world war ii was by far the deadliest conflict in history, resulting in an estimated 70 to 85 million fatalities, mostly among civilians. tens of millions died due to genocides (including the holocaust), starvation, massacres, and disease. in the wake of axis defeat, germany, austria and japan were occupied, and war crimes tribunals were conducted against german and japanese leaders.\nthe causes of world war ii are debated, but contributing factors included the second italo-ethiopian war, spanish civil war, second sino-japanese war, soviet–japanese border conflicts, the rise of fascism in europe, and european tensions in the aftermath of world war i. world war ii is generally considered to have begun on 1 september 1939, when nazi germany, under adolf hitler, invaded poland. the united kingdom and france subsequently declared war on germany on 3 september. under the molotov–ribbentrop pact of august 1939, germany and the soviet union had partitioned poland and marked out their "spheres of influence" across finland, estonia, latvia, lithuania and romania. from late 1939 to early 1941, in a series of campaigns and treaties, germany conquered or controlled much of continental europe, in a military alliance with italy, japan and other countries called the axis. following the onset of campaigns in north africa and east africa, and the fall of france in mid-1940, the war continued primarily between the euro\n'

# %%
AllWords = list(set(T.split()))
AllWords
# Out:
# ['many',
#  'weapons',
#  'strategic',
#  'global',
#  'generally',
#  'great',
#  'participants',
#  'died',
#  '1939',
#  'far',
#  'following',
#  'sino-japanese',
#  'all',
#  'major',
#  'september',
#  'were',
#  'soviet',
#  'poland',
#  'as',
#  'lithuania',
#  'due',
#  'occupied,',
#  'fall',
#  'countries,',
#  'resources.',
#  'mid-1940,',
#  'debated,',
#  'is',
#  'enabling',
#  'resulting',
#  'under',
#  'factors',
#  '70',
#  'countries',
#  'partitioned',
#  'genocides',
#  'conflict',
#  'causes',
#  'against',
#  'an',
#  'fascism',
#  'civilians.',
#  'tens',
#  'war',
#  'powers,',
#  'aftermath',
#  "world's",
#  'total',
#  'kingdom',
#  'japan',
#  'are',
#  'civilian',
#  'role,',
#  'alliance',
#  'contributing',
#  'when',
#  '85',
#  'ii',
#  '1941,',
#  'conflicts,',
#  'north',
#  'german',
#  'adolf',
#  'threw',
#  'had',
#  '"spheres',
#  'behind',
#  'and',
#  'vast',
#  'controlled',
#  'japanese',
#  'majority',
#  'from',
#  'centres',
#  'was',
#  'starvation,',
#  'conducted',
#  'industrial,',
#  'in',
#  'i.',
#  'ever',
#  'late',
#  'subsequently',
#  '1945.',
#  'campaigns',
#  'war.',
#  'among',
#  'part',
#  'mostly',
#  'rise',
#  'or',
#  'influence"',
#  'alliances:',
#  'million',
#  'series',
#  'austria',
#  'population',
#  'distinction',
#  '1',
#  'estonia,',
#  'continued',
#  'this',
#  'military',
#  'axis.',
#  'italy,',
#  'september.',
#  'africa',
#  'civil',
#  'two',
#  'hitler,',
#  'europe,',
#  'opposing',
#  'history,',
#  'conquered',
#  'pact',
#  'germany,',
#  'begun',
#  'early',
#  'romania.',
#  'wwii',
#  'fatalities,',
#  'spanish',
#  'often',
#  'considered',
#  'marked',
#  'included',
#  'primarily',
#  'with',
#  'scientific',
#  'defeat,',
#  'to',
#  'holocaust),',
#  'latvia,',
#  'on',
#  'poland.',
#  'much',
#  'european',
#  'crimes',
#  '(including',
#  'leaders.',
#  'their',
#  'lasted',
#  'tensions',
#  'continental',
#  'soviet–japanese',
#  'have',
#  'second',
#  'other',
#  'including',
#  'germany',
#  'border',
#  'italo-ethiopian',
#  'delivery',
#  'wake',
#  '3',
#  'only',
#  'blurring',
#  'called',
#  'bombing',
#  'finland,',
#  'by',
#  'that',
#  'massacres,',
#  'between',
#  'invaded',
#  'treaties,',
#  'fought',
#  'world',
#  'estimated',
#  'ww2,',
#  'of',
#  'tribunals',
#  'east',
#  'aircraft',
#  'nuclear',
#  'used',
#  'august',
#  'france',
#  'abbreviated',
#  'africa,',
#  'played',
#  'war,',
#  'millions',
#  'out',
#  'union',
#  'a',
#  'disease.',
#  '1939,',
#  'molotov–ribbentrop',
#  'allies',
#  'capabilities',
#  'economic,',
#  'across',
#  'but',
#  'euro',
#  'onset',
#  'nazi',
#  'the',
#  'deadliest',
#  'axis',
#  'united',
#  'declared']

# %%
len(AllWords)
# Out:
# 202

# %%
len(T.split())
# Out:
# 319

# %%
W2I = {i:j for i,j in zip(AllWords,range(1,len(AllWords)+1)) }
I2W = {i:j for j,i in W2I.items() }
W2I
# Out:
# {'many': 1,
#  'weapons': 2,
#  'strategic': 3,
#  'global': 4,
#  'generally': 5,
#  'great': 6,
#  'participants': 7,
#  'died': 8,
#  '1939': 9,
#  'far': 10,
#  'following': 11,
#  'sino-japanese': 12,
#  'all': 13,
#  'major': 14,
#  'september': 15,
#  'were': 16,
#  'soviet': 17,
#  'poland': 18,
#  'as': 19,
#  'lithuania': 20,
#  'due': 21,
#  'occupied,': 22,
#  'fall': 23,
#  'countries,': 24,
#  'resources.': 25,
#  'mid-1940,': 26,
#  'debated,': 27,
#  'is': 28,
#  'enabling': 29,
#  'resulting': 30,
#  'under': 31,
#  'factors': 32,
#  '70': 33,
#  'countries': 34,
#  'partitioned': 35,
#  'genocides': 36,
#  'conflict': 37,
#  'causes': 38,
#  'against': 39,
#  'an': 40,
#  'fascism': 41,
#  'civilians.': 42,
#  'tens': 43,
#  'war': 44,
#  'powers,': 45,
#  'aftermath': 46,
#  "world's": 47,
#  'total': 48,
#  'kingdom': 49,
#  'japan': 50,
#  'are': 51,
#  'civilian': 52,
#  'role,': 53,
#  'alliance': 54,
#  'contributing': 55,
#  'when': 56,
#  '85': 57,
#  'ii': 58,
#  '1941,': 59,
#  'conflicts,': 60,
#  'north': 61,
#  'german': 62,
#  'adolf': 63,
#  'threw': 64,
#  'had': 65,
#  '"spheres': 66,
#  'behind': 67,
#  'and': 68,
#  'vast': 69,
#  'controlled': 70,
#  'japanese': 71,
#  'majority': 72,
#  'from': 73,
#  'centres': 74,
#  'was': 75,
#  'starvation,': 76,
#  'conducted': 77,
#  'industrial,': 78,
#  'in': 79,
#  'i.': 80,
#  'ever': 81,
#  'late': 82,
#  'subsequently': 83,
#  '1945.': 84,
#  'campaigns': 85,
#  'war.': 86,
#  'among': 87,
#  'part': 88,
#  'mostly': 89,
#  'rise': 90,
#  'or': 91,
#  'influence"': 92,
#  'alliances:': 93,
#  'million': 94,
#  'series': 95,
#  'austria': 96,
#  'population': 97,
#  'distinction': 98,
#  '1': 99,
#  'estonia,': 100,
#  'continued': 101,
#  'this': 102,
#  'military': 103,
#  'axis.': 104,
#  'italy,': 105,
#  'september.': 106,
#  'africa': 107,
#  'civil': 108,
#  'two': 109,
#  'hitler,': 110,
#  'europe,': 111,
#  'opposing': 112,
#  'history,': 113,
#  'conquered': 114,
#  'pact': 115,
#  'germany,': 116,
#  'begun': 117,
#  'early': 118,
#  'romania.': 119,
#  'wwii': 120,
#  'fatalities,': 121,
#  'spanish': 122,
#  'often': 123,
#  'considered': 124,
#  'marked': 125,
#  'included': 126,
#  'primarily': 127,
#  'with': 128,
#  'scientific': 129,
#  'defeat,': 130,
#  'to': 131,
#  'holocaust),': 132,
#  'latvia,': 133,
#  'on': 134,
#  'poland.': 135,
#  'much': 136,
#  'european': 137,
#  'crimes': 138,
#  '(including': 139,
#  'leaders.': 140,
#  'their': 141,
#  'lasted': 142,
#  'tensions': 143,
#  'continental': 144,
#  'soviet–japanese': 145,
#  'have': 146,
#  'second': 147,
#  'other': 148,
#  'including': 149,
#  'germany': 150,
#  'border': 151,
#  'italo-ethiopian': 152,
#  'delivery': 153,
#  'wake': 154,
#  '3': 155,
#  'only': 156,
#  'blurring': 157,
#  'called': 158,
#  'bombing': 159,
#  'finland,': 160,
#  'by': 161,
#  'that': 162,
#  'massacres,': 163,
#  'between': 164,
#  'invaded': 165,
#  'treaties,': 166,
#  'fought': 167,
#  'world': 168,
#  'estimated': 169,
#  'ww2,': 170,
#  'of': 171,
#  'tribunals': 172,
#  'east': 173,
#  'aircraft': 174,
#  'nuclear': 175,
#  'used': 176,
#  'august': 177,
#  'france': 178,
#  'abbreviated': 179,
#  'africa,': 180,
#  'played': 181,
#  'war,': 182,
#  'millions': 183,
#  'out': 184,
#  'union': 185,
#  'a': 186,
#  'disease.': 187,
#  '1939,': 188,
#  'molotov–ribbentrop': 189,
#  'allies': 190,
#  'capabilities': 191,
#  'economic,': 192,
#  'across': 193,
#  'but': 194,
#  'euro': 195,
#  'onset': 196,
#  'nazi': 197,
#  'the': 198,
#  'deadliest': 199,
#  'axis': 200,
#  'united': 201,
#  'declared': 202}

# %%
I2W
# Out:
# {1: 'many',
#  2: 'weapons',
#  3: 'strategic',
#  4: 'global',
#  5: 'generally',
#  6: 'great',
#  7: 'participants',
#  8: 'died',
#  9: '1939',
#  10: 'far',
#  11: 'following',
#  12: 'sino-japanese',
#  13: 'all',
#  14: 'major',
#  15: 'september',
#  16: 'were',
#  17: 'soviet',
#  18: 'poland',
#  19: 'as',
#  20: 'lithuania',
#  21: 'due',
#  22: 'occupied,',
#  23: 'fall',
#  24: 'countries,',
#  25: 'resources.',
#  26: 'mid-1940,',
#  27: 'debated,',
#  28: 'is',
#  29: 'enabling',
#  30: 'resulting',
#  31: 'under',
#  32: 'factors',
#  33: '70',
#  34: 'countries',
#  35: 'partitioned',
#  36: 'genocides',
#  37: 'conflict',
#  38: 'causes',
#  39: 'against',
#  40: 'an',
#  41: 'fascism',
#  42: 'civilians.',
#  43: 'tens',
#  44: 'war',
#  45: 'powers,',
#  46: 'aftermath',
#  47: "world's",
#  48: 'total',
#  49: 'kingdom',
#  50: 'japan',
#  51: 'are',
#  52: 'civilian',
#  53: 'role,',
#  54: 'alliance',
#  55: 'contributing',
#  56: 'when',
#  57: '85',
#  58: 'ii',
#  59: '1941,',
#  60: 'conflicts,',
#  61: 'north',
#  62: 'german',
#  63: 'adolf',
#  64: 'threw',
#  65: 'had',
#  66: '"spheres',
#  67: 'behind',
#  68: 'and',
#  69: 'vast',
#  70: 'controlled',
#  71: 'japanese',
#  72: 'majority',
#  73: 'from',
#  74: 'centres',
#  75: 'was',
#  76: 'starvation,',
#  77: 'conducted',
#  78: 'industrial,',
#  79: 'in',
#  80: 'i.',
#  81: 'ever',
#  82: 'late',
#  83: 'subsequently',
#  84: '1945.',
#  85: 'campaigns',
#  86: 'war.',
#  87: 'among',
#  88: 'part',
#  89: 'mostly',
#  90: 'rise',
#  91: 'or',
#  92: 'influence"',
#  93: 'alliances:',
#  94: 'million',
#  95: 'series',
#  96: 'austria',
#  97: 'population',
#  98: 'distinction',
#  99: '1',
#  100: 'estonia,',
#  101: 'continued',
#  102: 'this',
#  103: 'military',
#  104: 'axis.',
#  105: 'italy,',
#  106: 'september.',
#  107: 'africa',
#  108: 'civil',
#  109: 'two',
#  110: 'hitler,',
#  111: 'europe,',
#  112: 'opposing',
#  113: 'history,',
#  114: 'conquered',
#  115: 'pact',
#  116: 'germany,',
#  117: 'begun',
#  118: 'early',
#  119: 'romania.',
#  120: 'wwii',
#  121: 'fatalities,',
#  122: 'spanish',
#  123: 'often',
#  124: 'considered',
#  125: 'marked',
#  126: 'included',
#  127: 'primarily',
#  128: 'with',
#  129: 'scientific',
#  130: 'defeat,',
#  131: 'to',
#  132: 'holocaust),',
#  133: 'latvia,',
#  134: 'on',
#  135: 'poland.',
#  136: 'much',
#  137: 'european',
#  138: 'crimes',
#  139: '(including',
#  140: 'leaders.',
#  141: 'their',
#  142: 'lasted',
#  143: 'tensions',
#  144: 'continental',
#  145: 'soviet–japanese',
#  146: 'have',
#  147: 'second',
#  148: 'other',
#  149: 'including',
#  150: 'germany',
#  151: 'border',
#  152: 'italo-ethiopian',
#  153: 'delivery',
#  154: 'wake',
#  155: '3',
#  156: 'only',
#  157: 'blurring',
#  158: 'called',
#  159: 'bombing',
#  160: 'finland,',
#  161: 'by',
#  162: 'that',
#  163: 'massacres,',
#  164: 'between',
#  165: 'invaded',
#  166: 'treaties,',
#  167: 'fought',
#  168: 'world',
#  169: 'estimated',
#  170: 'ww2,',
#  171: 'of',
#  172: 'tribunals',
#  173: 'east',
#  174: 'aircraft',
#  175: 'nuclear',
#  176: 'used',
#  177: 'august',
#  178: 'france',
#  179: 'abbreviated',
#  180: 'africa,',
#  181: 'played',
#  182: 'war,',
#  183: 'millions',
#  184: 'out',
#  185: 'union',
#  186: 'a',
#  187: 'disease.',
#  188: '1939,',
#  189: 'molotov–ribbentrop',
#  190: 'allies',
#  191: 'capabilities',
#  192: 'economic,',
#  193: 'across',
#  194: 'but',
#  195: 'euro',
#  196: 'onset',
#  197: 'nazi',
#  198: 'the',
#  199: 'deadliest',
#  200: 'axis',
#  201: 'united',
#  202: 'declared'}

# %%
','.join([str(W2I[i]) for i in T.lower().split()])
# Out:
# '167,43,57,90,197,146,167,181,122,178,18,119,90,169,74,185,3,36,161,141,72,8,130,83,197,68,71,170,197,46,23,148,12,170,197,5,44,166,18,87,170,108,111,102,92,197,189,67,197,103,0,6,63,140,191,77,67,128,190,66,101,47,181,156,197,97,163,51,67,102,24,173,180,185,13,52,28,197,2,158,170,96,73,67,197,152,170,197,155,108,174,1,80,175,78,85,167,43,57,74,160,9,197,198,36,78,112,29,78,39,168,32,130,56,93,120,88,86,41,42,170,182,7,20,130,35,138,197,131,75,162,67,186,78,197,153,170,199,129,115,95,67,49,15,21,67,43,137,171,15,76,38,61,67,70,139,197,37,170,167,43,57,50,26,193,54,31,125,197,146,151,181,121,107,181,146,11,181,144,150,59,197,89,170,40,78,110,67,136,142,78,197,45,170,167,43,79,167,43,57,27,4,123,130,145,116,133,98,14,187,55,196,115,30,62,109,164,134,197,200,48,67,177,82,201,43,133,149,133,154,105,30,197,188,114,170,176,187,149,67,197,16,184,64,34,17,67,124,183,140,65,170,91,192,159,99,132,19,67,118,72,81,8,130,117,58,78,185,94,170,84,67,165,149,113,90,69,135,170,143,110,78,185,102,53,127,104,49,67,147,33,157,197,103,10,197,195,170,84,78,60,106,67,172,179,67,197,22,170,177,78,25,197,43,100,126,163,197,194'
